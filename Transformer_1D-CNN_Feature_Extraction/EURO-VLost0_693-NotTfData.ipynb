# %%
# %matplotlib inline

from os import listdir, makedirs
from os.path import isfile, join, basename, splitext, isfile, exists
from datetime import datetime
from tensorflow.keras.metrics import top_k_categorical_accuracy, CategoricalHinge, Recall, Precision
import numpy as np
import pandas as pd

from tqdm import tqdm_notebook

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import metrics

import tensorflow.keras
from tensorflow.compat.v2.keras.layers import Input

import matplotlib.pyplot as plt
import seaborn as sns

import random, os, sys
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
import tensorflow as tf
from tensorflow.python.keras.layers import Layer
tf.compat.v1.disable_eager_execution
pd.set_option('precision', 30)
np.set_printoptions(precision = 30)

# np.random.seed(368)
# tf.random.set_seed(368)

# %%
xfile = 'C:\workspace\j6stock\XOpenHighLowCloseVol_tp10_cl10.txt'

seq_len = 60*24*2 # 3 days + 2 features is enough memory
batch_size = 2048*2+200       # Batch size
mini_batch_size = 64       # Batch size

learning_rate = 0.001  #0.0001  # Learning rate (default is 0.001)
epochs = 1


y_column = 6
compute_val_at = 0
acc_filtered_r = 0.8


import tensorflow as tf
from tensorflow.python import debug as tf_debug
from sklearn import preprocessing
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt2
import pandas as pd
from pandas import datetime
import math, time
import itertools
from sklearn import preprocessing
import datetime
from sklearn.metrics import mean_squared_error
from math import sqrt
#from keras.models import Sequential
#from keras.layers.core import Dense, Dropout, Activation
#from keras.layers.recurrent import LSTM
#from keras.models import load_model
#import keras
import pandas as pd ## can be remove once pandas_datareader 0.7 using
pd.core.common.is_list_like = pd.api.types.is_list_like ## can be remove once pandas_datareader 0.7 using
import pandas_datareader.data as web
import h5py
import os

#from keras import backend as K

def make_window_dataset(ds, window_size=5, shift=1, stride=1):
    windows = ds.window(window_size, shift=shift, stride=stride)

    def sub_to_batch(sub, y):
        print (sub)
        print (y)
        s = sub.batch(window_size, drop_remainder=True)
        yy = y.batch(window_size, drop_remainder=True)
        return (s, yy)

    windows = windows.flat_map(sub_to_batch)
    return windows


def get_stock_data(normalize=True, ma=[]):
    """
    Return a dataframe of that stock and normalize all the values. 
    (Optional: create moving average)
    """
    df = pd.read_csv(filepath_or_buffer  = xfile )
    #TODO Use previous close instead of open
    df['change'] = df['close'] - df['open']
    df['tail'] = df['low']
    for i, row in df.iterrows():
        df.at[i, 'high'] = df.at[i, 'high'] - (df.at[i, 'open'] if df.at[i, 'open'] > df.at[i, 'close'] else df.at[i, 'close'])
        df.at[i, 'low'] = (df.at[i, 'close'] if df.at[i, 'close'] < df.at[i, 'open'] else df.at[i, 'open']) - df.at[i, 'low']
        df.at[i, 'tail'] = df.at[i, 'high'] if df.at[i, 'high'] > df.at[i, 'low'] else ( df.at[i, 'low'] * -1)
    df.dropna(inplace=True)
    df = df.drop('open', axis=1)
    # Moving Average    
    if ma != []:
        for moving in ma:
            df['{}ma'.format(moving)] = df['close'].rolling(window=moving).mean()
    df.dropna(inplace=True)
    
    
        
    if normalize:
        min_max_scaler = preprocessing.MinMaxScaler()
        #df['open'] = min_max_scaler.fit_transform(df.open.values.reshape(-1,1))
        #df['high'] = min_max_scaler.fit_transform(df.high.values.reshape(-1,1))
        #df['low'] = min_max_scaler.fit_transform(df.low.values.reshape(-1,1))
        #df['vol'] = min_max_scaler.fit_transform(df.vol.values.reshape(-1,1))
        df['close'] = min_max_scaler.fit_transform(df['close'].values.reshape(-1,1))
        df['change'] = min_max_scaler.fit_transform(df['change'].values.reshape(-1,1))
        df['tail'] = min_max_scaler.fit_transform(df['tail'].values.reshape(-1,1))
        if ma != []:
            for moving in ma:
                df['{}ma'.format(moving)] = min_max_scaler.fit_transform(df['{}ma'.format(moving)].values.reshape(-1,1))  
    df.dropna(inplace=True)
               
    # Move y_result to the rightmost for the ease of training
    adj_close = df['y_result']
    df.drop(labels=['y_result'], axis=1, inplace=True)
    df = pd.concat([df, adj_close], axis=1)
    
    #drop for wavenet and not enough memory
    #df.drop(labels=['change'], axis=1, inplace=True)
    df.drop(labels=['high'], axis=1, inplace=True)
    df.drop(labels=['low'], axis=1, inplace=True)
    
    return df

#df = get_stock_data( ma=[50, 100, 200])
df = get_stock_data()

amount_of_features = len(df.columns)-1

def load_data(stock, seq_len):
    print ("Amount of features = {}".format(amount_of_features))
    data = stock.as_matrix()
    sequence_length = seq_len + 1 # index starting from 0
    x_result = []
    y_result = []
    for index in range(seq_len, len(data) ): # maxmimum date = lastest date - sequence length
        x_result.append(data[index-seq_len: index,:-1]) # index : index + 22days
        y_result.append(data[index ,amount_of_features]);

    #print('---', data[0])
    #print('---', x_result[0])
    #print('---', y_result[0])
    x_result = np.array(x_result)
    y_result = np.array(y_result)
    row = round(0.6 * y_result.shape[0]) # 80% split
    print ("Amount of training data = {}".format(0.9 * x_result.shape[0]))
    print ("Amount of testing data = {}".format(0.1 * y_result.shape[0]))
     
    X_train = x_result[:int(row), :] # 90% date
    y_train = y_result[:int(row)] # 90% date
        

    X_test = x_result[int(row):, :]
    y_test = y_result[int(row):]
    # filter for 1 and -1 for validation only
    X_test = X_test[y_test[:]!=0,:]
    y_test = y_test[y_test[:]!=0]
    #print(result.shape[0], len(y_result), int(row), y_result[int(row):])
    #X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], amount_of_features-1))
    #X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], amount_of_features-1))
    
    return [X_train, y_train, X_test, y_test]



classes = [1, 0, -1]
lb = preprocessing.LabelBinarizer()
lb.fit(classes)
lb.transform([-1, 0, 1])

X_tr, lab_tr, X_vld, lab_vld = load_data(df, seq_len)
y_tr = lb.transform(lab_tr)
y_vld = lb.transform(lab_vld)


train_X = X_tr
train_y = y_tr
valid_X = X_vld
valid_y = y_vld
test_X = X_vld
test_y = y_vld
print(train_X.shape)
print(train_y[0])
print(train_y[1])
print(train_y[2])
# Out:
# Amount of features = 3
# C:\Users\Admin\Anaconda3\envs\Transformer_1D-CNN_Feature_Extraction\lib\site-packages\ipykernel_launcher.py:114: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# Amount of training data = 259614.0
# Amount of testing data = 28846.0
# (173076, 2880, 3)
# [0 1 0]
# [0 1 0]
# [0 0 1]

# %%
# https://www.kaggle.com/shujian/transformer-with-lstm

try:
    from dataloader import TokenList, pad_to_longest
    # for transformer
except: pass



embed_size = 60

class LayerNormalization(Layer):
    def __init__(self, eps=1e-6, **kwargs):
        self.eps = eps
        super(LayerNormalization, self).__init__(**kwargs)
    def build(self, input_shape):
        self.gamma = self.add_weight(name='gamma', shape=input_shape[-1:],
                                     initializer=Ones(), trainable=True)
        self.beta = self.add_weight(name='beta', shape=input_shape[-1:],
                                    initializer=Zeros(), trainable=True)
        super(LayerNormalization, self).build(input_shape)
    def call(self, x):
        mean = K.mean(x, axis=-1, keepdims=True)
        std = K.std(x, axis=-1, keepdims=True)
        return self.gamma * (x - mean) / (std + self.eps) + self.beta
    def compute_output_shape(self, input_shape):
        return input_shape

class ScaledDotProductAttention():
    def __init__(self, d_model, attn_dropout=0.1):
        self.temper = np.sqrt(d_model)
        self.dropout = Dropout(attn_dropout)
    def __call__(self, q, k, v, mask):
        attn = Lambda(lambda x:K.batch_dot(x[0],x[1],axes=[2,2])/self.temper)([q, k])
        if mask is not None:
            mmask = Lambda(lambda x:(-1e+10)*(1-x))(mask)
            attn = Add()([attn, mmask])
        attn = Activation('softmax')(attn)
        attn = self.dropout(attn)
        output = Lambda(lambda x:K.batch_dot(x[0], x[1]))([attn, v])
        return output, attn

class MultiHeadAttention():
    # mode 0 - big martixes, faster; mode 1 - more clear implementation
    def __init__(self, n_head, d_model, d_k, d_v, dropout, mode=0, use_norm=True):
        self.mode = mode
        self.n_head = n_head
        self.d_k = d_k
        self.d_v = d_v
        self.dropout = dropout
        if mode == 0:
            self.qs_layer = Dense(n_head*d_k, use_bias=False)
            self.ks_layer = Dense(n_head*d_k, use_bias=False)
            self.vs_layer = Dense(n_head*d_v, use_bias=False)
        elif mode == 1:
            self.qs_layers = []
            self.ks_layers = []
            self.vs_layers = []
            for _ in range(n_head):
                self.qs_layers.append(TimeDistributed(Dense(d_k, use_bias=False)))
                self.ks_layers.append(TimeDistributed(Dense(d_k, use_bias=False)))
                self.vs_layers.append(TimeDistributed(Dense(d_v, use_bias=False)))
        self.attention = ScaledDotProductAttention(d_model)
        self.layer_norm = LayerNormalization() if use_norm else None
        self.w_o = TimeDistributed(Dense(d_model))

    def __call__(self, q, k, v, mask=None):
        d_k, d_v = self.d_k, self.d_v
        n_head = self.n_head

        if self.mode == 0:
            qs = self.qs_layer(q)  # [batch_size, len_q, n_head*d_k]
            ks = self.ks_layer(k)
            vs = self.vs_layer(v)

            def reshape1(x):
                s = tf.shape(x)   # [batch_size, len_q, n_head * d_k]
                x = tf.reshape(x, [s[0], s[1], n_head, d_k])
                x = tf.transpose(x, [2, 0, 1, 3])  
                x = tf.reshape(x, [-1, s[1], d_k])  # [n_head * batch_size, len_q, d_k]
                return x
            qs = Lambda(reshape1)(qs)
            ks = Lambda(reshape1)(ks)
            vs = Lambda(reshape1)(vs)

            if mask is not None:
                mask = Lambda(lambda x:K.repeat_elements(x, n_head, 0))(mask)
            head, attn = self.attention(qs, ks, vs, mask=mask)  
                
            def reshape2(x):
                s = tf.shape(x)   # [n_head * batch_size, len_v, d_v]
                x = tf.reshape(x, [n_head, -1, s[1], s[2]]) 
                x = tf.transpose(x, [1, 2, 0, 3])
                x = tf.reshape(x, [-1, s[1], n_head*d_v])  # [batch_size, len_v, n_head * d_v]
                return x
            head = Lambda(reshape2)(head)
        elif self.mode == 1:
            heads = []; attns = []
            for i in range(n_head):
                qs = self.qs_layers[i](q)   
                ks = self.ks_layers[i](k) 
                vs = self.vs_layers[i](v) 
                head, attn = self.attention(qs, ks, vs, mask)
                heads.append(head); attns.append(attn)
            head = Concatenate()(heads) if n_head > 1 else heads[0]
            attn = Concatenate()(attns) if n_head > 1 else attns[0]

        outputs = self.w_o(head)
        outputs = Dropout(self.dropout)(outputs)
        if not self.layer_norm: return outputs, attn
        # outputs = Add()([outputs, q]) # sl: fix
        return self.layer_norm(outputs), attn

class PositionwiseFeedForward():
    def __init__(self, d_hid, d_inner_hid, dropout=0.1):
        self.w_1 = Conv1D(d_inner_hid, 1, activation='relu')
        self.w_2 = Conv1D(d_hid, 1)
        self.layer_norm = LayerNormalization()
        self.dropout = Dropout(dropout)
    def __call__(self, x):
        output = self.w_1(x) 
        output = self.w_2(output)
        output = self.dropout(output)
        output = Add()([output, x])
        return self.layer_norm(output)

class EncoderLayer():
    def __init__(self, d_model, d_inner_hid, n_head, d_k, d_v, dropout=0.1):
        self.self_att_layer = MultiHeadAttention(n_head, d_model, d_k, d_v, dropout=dropout)
        self.pos_ffn_layer  = PositionwiseFeedForward(d_model, d_inner_hid, dropout=dropout)
    def __call__(self, enc_input, mask=None):
        output, slf_attn = self.self_att_layer(enc_input, enc_input, enc_input, mask=mask)
        output = self.pos_ffn_layer(output)
        return output, slf_attn


def GetPosEncodingMatrix(max_len, d_emb):
    pos_enc = np.array([
        [pos / np.power(10000, 2 * (j // 2) / d_emb) for j in range(d_emb)] 
        if pos != 0 else np.zeros(d_emb) 
            for pos in range(max_len)
            ])
    pos_enc[1:, 0::2] = np.sin(pos_enc[1:, 0::2]) # dim 2i
    pos_enc[1:, 1::2] = np.cos(pos_enc[1:, 1::2]) # dim 2i+1
    return pos_enc

def GetPadMask(q, k):
    ones = K.expand_dims(K.ones_like(q, 'float32'), -1)
    mask = K.cast(K.expand_dims(K.not_equal(k, 0), 1), 'float32')
    mask = K.batch_dot(ones, mask, axes=[2,1])
    return mask

def GetSubMask(s):
    len_s = tf.shape(s)[1]
    bs = tf.shape(s)[:1]
    mask = K.cumsum(tf.eye(len_s, batch_shape=bs), 1)
    return mask

# %%
def CnnTransformerModel():
#    i = tf.compat.v2.keras.layers.Flatten(input_shape=(batch_size, amount_of_features))
    i = tf.compat.v2.keras.layers.Input(shape = (seq_len, amount_of_features)#, batch_size=mini_batch_size
                                       )
    x = tf.compat.v2.keras.layers.Convolution1D(16, kernel_size = 10, strides = 7, activation='relu')(i)
    x = tf.compat.v2.keras.layers.Convolution1D(16, kernel_size = 8, strides = 5, activation='relu')(x)
    x = tf.compat.v2.keras.layers.Convolution1D(16, kernel_size = 6, strides = 4, activation='relu')(x)
    x = tf.compat.v2.keras.layers.Convolution1D(16, kernel_size = 4, strides = 2, activation='relu')(x)
#    x = Convolution1D(16, kernel_size = 10, strides = 10, activation='relu')(i)
#    x = Convolution1D(16, kernel_size = 10, strides = 10, activation='relu')(x)
#    x = Convolution1D(16, kernel_size = 10, strides = 10, activation='relu')(x)
 
#    x = (CuDNNLSTM(16, return_sequences = True, return_state = False))(x)
    x, slf_attn = MultiHeadAttention(n_head=15, d_model=300, d_k=64, d_v=64, dropout=0.3)(x, x, x)
    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)
    concat = concatenate([avg_pool, max_pool])
    y = Dense(3,activation = 'relu')(concat)
    

    return Model(inputs = [i], outputs = [y])

# %%
model = CnnTransformerModel()
optimizer = tf.keras.optimizers.Adam(lr=0.010, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer=optimizer, 
                          loss='categorical_crossentropy' 
#              , metrics=[ Recall(thresholds=0.5, class_id=0, top_k=1)
                        #          , Recall(thresholds=0.5, class_id=2, top_k=1)
#                                    , Precision(thresholds=0.5, class_id=0, top_k=1)
#                                   , Precision(thresholds=0.5, class_id=2, top_k=1)
#                                  ]
             )
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 2880, 3)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 411, 16)      496         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 81, 16)       2064        conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 19, 16)       1552        conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 8, 16)        1040        conv1d_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 8, 960)       15360       conv1d_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 8, 960)       15360       conv1d_3[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, None, 64)     0           dense[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, 64)     0           dense_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, None, None)   0           lambda[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, None, None)   0           lambda_3[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8, 960)       15360       conv1d_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, None, None)   0           activation[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, None, 64)     0           dense_2[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, None, 64)     0           dropout[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, None, 960)    0           lambda_4[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 300)    288300      lambda_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, 300)    0           time_distributed[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, None, 300)    600         dropout_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 300)          0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 300)          0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 600)          0           global_average_pooling1d[0][0]
#                                                                  global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 3)            1803        concatenate[0][0]
# ==================================================================================================
# Total params: 341,935
# Trainable params: 341,935
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# **Visualizing The Model Architecture**

# %%
from IPython.display import SVG
from tensorflow.python.keras.utils.vis_utils import model_to_dot
SVG(model_to_dot(model,show_shapes = True).create(prog='dot', format='svg'))

# %% [markdown]
# Train the model with early stopping

# %%
from datetime import datetime
logdir = "logs\\scalars\\" + datetime.now().strftime("%Y%m%d-%H%M%S")

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
weight_path="{}_weights.best.hdf5".format('stroke_lstm_model')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = True)


reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=10, verbose=1, mode='auto', epsilon=0.0001, cooldown=5, min_lr=0.001)
early = EarlyStopping(monitor="val_loss", 
                      mode="min", 
                      patience=30) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint
                  , early
                  , reduceLROnPlat
                  , tensorboard_callback
                 ]

from IPython.display import clear_output
model.fit(train_X, train_y,
                      validation_data = (valid_X, valid_y), 
                      batch_size = batch_size,
                      epochs = 500,
                      callbacks = callbacks_list)
#clear_output()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0930 17:50:21.416893 12716 callbacks.py:1781] `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# Train on 173076 samples, validate on 69938 samples
# W0930 17:50:21.663949 12716 summary_ops_v2.py:1110] Model failed to serialize as JSON. Ignoring... Layers with arguments in `__init__` must override `get_config`.
# Epoch 1/500
# W0930 17:50:22.347103 12716 deprecation.py:323] From C:\Users\Admin\Anaconda3\envs\Transformer_1D-CNN_Feature_Extraction\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1394: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 171840/173076 [============================>.] - ETA: 26:08 - loss: 8.20 - ETA: 12:56 - loss: 7.40 - ETA: 8:27 - loss: 7.1722 - ETA: 6:12 - loss: 7.082 - ETA: 4:51 - loss: 6.959 - ETA: 3:57 - loss: 6.908 - ETA: 3:18 - loss: 6.875 - ETA: 2:49 - loss: 6.855 - ETA: 2:27 - loss: 6.843 - ETA: 2:08 - loss: 6.827 - ETA: 1:53 - loss: 6.806 - ETA: 1:41 - loss: 6.794 - ETA: 1:30 - loss: 6.773 - ETA: 1:21 - loss: 6.766 - ETA: 1:13 - loss: 6.749 - ETA: 1:06 - loss: 6.748 - ETA: 1:00 - loss: 6.738 - ETA: 54s - loss: 6.737 - ETA: 49s - loss: 6.73 - ETA: 49s - loss: 6.74 - ETA: 45s - loss: 6.74 - ETA: 41s - loss: 6.73 - ETA: 37s - loss: 6.74 - ETA: 44s - loss: 6.73 - ETA: 41s - loss: 6.73 - ETA: 37s - loss: 6.72 - ETA: 33s - loss: 6.71 - ETA: 30s - loss: 6.71 - ETA: 27s - loss: 6.71 - ETA: 24s - loss: 6.70 - ETA: 21s - loss: 6.70 - ETA: 19s - loss: 6.69 - ETA: 16s - loss: 6.69 - ETA: 13s - loss: 6.69 - ETA: 11s - loss: 6.68 - ETA: 9s - loss: 6.6827 - ETA: 6s - loss: 6.679 - ETA: 4s - loss: 6.678 - ETA: 2s - loss: 6.668 - ETA: 0s - loss: 6.6681
# Epoch 00001: val_loss improved from inf to 0.69856, saving model to stroke_lstm_model_weights.best.hdf5
# 173076/173076 [==============================] - 110s 638us/sample - loss: 6.6697 - val_loss: 0.6986
# Epoch 2/500
# 171840/173076 [============================>.] - ETA: 1:09 - loss: 6.664 - ETA: 1:02 - loss: 6.628 - ETA: 59s - loss: 6.593 - ETA: 1:00 - loss: 6.596 - ETA: 58s - loss: 6.596 - ETA: 56s - loss: 6.60 - ETA: 54s - loss: 6.62 - ETA: 52s - loss: 6.64 - ETA: 51s - loss: 6.63 - ETA: 50s - loss: 6.62 - ETA: 49s - loss: 6.61 - ETA: 48s - loss: 6.60 - ETA: 47s - loss: 6.61 - ETA: 46s - loss: 6.61 - ETA: 44s - loss: 6.61 - ETA: 44s - loss: 6.61 - ETA: 40s - loss: 6.60 - ETA: 37s - loss: 6.61 - ETA: 34s - loss: 6.61 - ETA: 32s - loss: 6.62 - ETA: 29s - loss: 6.62 - ETA: 28s - loss: 6.61 - ETA: 26s - loss: 6.61 - ETA: 24s - loss: 6.62 - ETA: 22s - loss: 6.62 - ETA: 20s - loss: 6.63 - ETA: 18s - loss: 6.62 - ETA: 17s - loss: 6.61 - ETA: 15s - loss: 6.61 - ETA: 14s - loss: 6.60 - ETA: 12s - loss: 6.60 - ETA: 11s - loss: 6.60 - ETA: 9s - loss: 6.6153 - ETA: 8s - loss: 6.616 - ETA: 6s - loss: 6.616 - ETA: 5s - loss: 6.619 - ETA: 4s - loss: 6.617 - ETA: 2s - loss: 6.620 - ETA: 1s - loss: 6.619 - ETA: 0s - loss: 6.6193
# Epoch 00002: val_loss did not improve from 0.69856
# 173076/173076 [==============================] - 73s 424us/sample - loss: 6.6197 - val_loss: 0.7011
# Epoch 3/500
# 171840/173076 [============================>.] - ETA: 47s - loss: 6.72 - ETA: 40s - loss: 6.72 - ETA: 35s - loss: 6.67 - ETA: 29s - loss: 6.67 - ETA: 26s - loss: 6.65 - ETA: 24s - loss: 6.61 - ETA: 22s - loss: 6.62 - ETA: 21s - loss: 6.60 - ETA: 21s - loss: 6.60 - ETA: 22s - loss: 6.63 - ETA: 27s - loss: 6.62 - ETA: 25s - loss: 6.61 - ETA: 23s - loss: 6.60 - ETA: 24s - loss: 6.60 - ETA: 23s - loss: 6.60 - ETA: 22s - loss: 6.60 - ETA: 20s - loss: 6.60 - ETA: 19s - loss: 6.61 - ETA: 17s - loss: 6.61 - ETA: 16s - loss: 6.62 - ETA: 15s - loss: 6.62 - ETA: 15s - loss: 6.62 - ETA: 15s - loss: 6.62 - ETA: 14s - loss: 6.61 - ETA: 13s - loss: 6.61 - ETA: 12s - loss: 6.61 - ETA: 11s - loss: 6.61 - ETA: 10s - loss: 6.62 - ETA: 10s - loss: 6.61 - ETA: 9s - loss: 6.6162 - ETA: 8s - loss: 6.613 - ETA: 7s - loss: 6.610 - ETA: 7s - loss: 6.608 - ETA: 6s - loss: 6.609 - ETA: 5s - loss: 6.612 - ETA: 4s - loss: 6.618 - ETA: 3s - loss: 6.616 - ETA: 2s - loss: 6.616 - ETA: 1s - loss: 6.615 - ETA: 0s - loss: 6.6197
# Epoch 00003: val_loss did not improve from 0.69856
# 173076/173076 [==============================] - 61s 355us/sample - loss: 6.6198 - val_loss: 0.7006
# Epoch 4/500
# 171840/173076 [============================>.] - ETA: 47s - loss: 6.66 - ETA: 31s - loss: 6.65 - ETA: 34s - loss: 6.69 - ETA: 27s - loss: 6.66 - ETA: 25s - loss: 6.64 - ETA: 24s - loss: 6.62 - ETA: 30s - loss: 6.66 - ETA: 28s - loss: 6.63 - ETA: 28s - loss: 6.64 - ETA: 27s - loss: 6.64 - ETA: 24s - loss: 6.65 - ETA: 22s - loss: 6.65 - ETA: 21s - loss: 6.65 - ETA: 20s - loss: 6.64 - ETA: 18s - loss: 6.63 - ETA: 17s - loss: 6.64 - ETA: 18s - loss: 6.63 - ETA: 18s - loss: 6.64 - ETA: 18s - loss: 6.63 - ETA: 18s - loss: 6.62 - ETA: 17s - loss: 6.62 - ETA: 16s - loss: 6.62 - ETA: 15s - loss: 6.63 - ETA: 13s - loss: 6.63 - ETA: 13s - loss: 6.63 - ETA: 12s - loss: 6.63 - ETA: 12s - loss: 6.62 - ETA: 11s - loss: 6.62 - ETA: 10s - loss: 6.61 - ETA: 9s - loss: 6.6198 - ETA: 8s - loss: 6.624 - ETA: 7s - loss: 6.627 - ETA: 6s - loss: 6.627 - ETA: 5s - loss: 6.625 - ETA: 4s - loss: 6.628 - ETA: 3s - loss: 6.626 - ETA: 2s - loss: 6.628 - ETA: 2s - loss: 6.623 - ETA: 1s - loss: 6.622 - ETA: 0s - loss: 6.6200
# Epoch 00004: val_loss did not improve from 0.69856
# 173076/173076 [==============================] - 58s 335us/sample - loss: 6.6198 - val_loss: 0.7027
# Epoch 5/500
# 171840/173076 [============================>.] - ETA: 23s - loss: 6.47 - ETA: 18s - loss: 6.51 - ETA: 15s - loss: 6.56 - ETA: 27s - loss: 6.55 - ETA: 26s - loss: 6.53 - ETA: 26s - loss: 6.55 - ETA: 24s - loss: 6.55 - ETA: 22s - loss: 6.57 - ETA: 21s - loss: 6.58 - ETA: 20s - loss: 6.60 - ETA: 23s - loss: 6.60 - ETA: 22s - loss: 6.59 - ETA: 20s - loss: 6.59 - ETA: 19s - loss: 6.59 - ETA: 18s - loss: 6.59 - ETA: 17s - loss: 6.60 - ETA: 16s - loss: 6.61 - ETA: 15s - loss: 6.61 - ETA: 15s - loss: 6.60 - ETA: 15s - loss: 6.61 - ETA: 14s - loss: 6.61 - ETA: 13s - loss: 6.61 - ETA: 12s - loss: 6.60 - ETA: 12s - loss: 6.61 - ETA: 12s - loss: 6.60 - ETA: 11s - loss: 6.60 - ETA: 10s - loss: 6.60 - ETA: 9s - loss: 6.6037 - ETA: 9s - loss: 6.605 - ETA: 8s - loss: 6.604 - ETA: 7s - loss: 6.608 - ETA: 6s - loss: 6.610 - ETA: 5s - loss: 6.612 - ETA: 4s - loss: 6.613 - ETA: 4s - loss: 6.615 - ETA: 3s - loss: 6.620 - ETA: 2s - loss: 6.622 - ETA: 1s - loss: 6.623 - ETA: 1s - loss: 6.620 - ETA: 0s - loss: 6.6196
# Epoch 00005: val_loss did not improve from 0.69856
# 173076/173076 [==============================] - 53s 308us/sample - loss: 6.6198 - val_loss: 0.6997
# Epoch 6/500
# 171840/173076 [============================>.] - ETA: 1:28 - loss: 6.348 - ETA: 1:08 - loss: 6.378 - ETA: 58s - loss: 6.464 - ETA: 1:00 - loss: 6.479 - ETA: 59s - loss: 6.527 - ETA: 58s - loss: 6.53 - ETA: 56s - loss: 6.57 - ETA: 52s - loss: 6.60 - ETA: 51s - loss: 6.60 - ETA: 45s - loss: 6.61 - ETA: 42s - loss: 6.62 - ETA: 39s - loss: 6.63 - ETA: 36s - loss: 6.63 - ETA: 34s - loss: 6.61 - ETA: 31s - loss: 6.61 - ETA: 29s - loss: 6.60 - ETA: 27s - loss: 6.60 - ETA: 25s - loss: 6.60 - ETA: 24s - loss: 6.60 - ETA: 22s - loss: 6.60 - ETA: 21s - loss: 6.62 - ETA: 19s - loss: 6.62 - ETA: 18s - loss: 6.62 - ETA: 17s - loss: 6.62 - ETA: 15s - loss: 6.62 - ETA: 14s - loss: 6.61 - ETA: 13s - loss: 6.61 - ETA: 12s - loss: 6.61 - ETA: 11s - loss: 6.61 - ETA: 10s - loss: 6.61 - ETA: 9s - loss: 6.6116 - ETA: 8s - loss: 6.616 - ETA: 7s - loss: 6.617 - ETA: 6s - loss: 6.617 - ETA: 5s - loss: 6.618 - ETA: 4s - loss: 6.622 - ETA: 3s - loss: 6.623 - ETA: 2s - loss: 6.620 - ETA: 1s - loss: 6.621 - ETA: 0s - loss: 6.6204
# Epoch 00006: val_loss did not improve from 0.69856
# 173076/173076 [==============================] - 57s 327us/sample - loss: 6.6198 - val_loss: 0.7002
# Epoch 7/500
# 171840/173076 [============================>.] - ETA: 34s - loss: 6.38 - ETA: 29s - loss: 6.45 - ETA: 24s - loss: 6.47 - ETA: 22s - loss: 6.51 - ETA: 21s - loss: 6.52 - ETA: 23s - loss: 6.55 - ETA: 25s - loss: 6.56 - ETA: 25s - loss: 6.58 - ETA: 25s - loss: 6.61 - ETA: 23s - loss: 6.60 - ETA: 23s - loss: 6.60 - ETA: 21s - loss: 6.61 - ETA: 22s - loss: 6.60 - ETA: 22s - loss: 6.60 - ETA: 20s - loss: 6.61 - ETA: 20s - loss: 6.61 - ETA: 19s - loss: 6.60 - ETA: 18s - loss: 6.60 - ETA: 17s - loss: 6.60 - ETA: 16s - loss: 6.59 - ETA: 15s - loss: 6.59 - ETA: 14s - loss: 6.59 - ETA: 13s - loss: 6.60 - ETA: 12s - loss: 6.60 - ETA: 11s - loss: 6.60 - ETA: 11s - loss: 6.60 - ETA: 10s - loss: 6.60 - ETA: 9s - loss: 6.6005 - ETA: 8s - loss: 6.597 - ETA: 7s - loss: 6.601 - ETA: 6s - loss: 6.605 - ETA: 6s - loss: 6.602 - ETA: 5s - loss: 6.600 - ETA: 4s - loss: 6.607 - ETA: 3s - loss: 6.614 - ETA: 3s - loss: 6.619 - ETA: 2s - loss: 6.619 - ETA: 1s - loss: 6.618 - ETA: 0s - loss: 6.617 - ETA: 0s - loss: 6.6191
# Epoch 00007: val_loss did not improve from 0.69856
# 173076/173076 [==============================] - 48s 280us/sample - loss: 6.6198 - val_loss: 0.6988
# Epoch 8/500
# 171840/173076 [============================>.] - ETA: 16s - loss: 6.56 - ETA: 24s - loss: 6.51 - ETA: 36s - loss: 6.53 - ETA: 31s - loss: 6.54 - ETA: 28s - loss: 6.57 - ETA: 28s - loss: 6.59 - ETA: 25s - loss: 6.60 - ETA: 24s - loss: 6.60 - ETA: 23s - loss: 6.58 - ETA: 21s - loss: 6.59 - ETA: 20s - loss: 6.58 - ETA: 20s - loss: 6.58 - ETA: 20s - loss: 6.59 - ETA: 21s - loss: 6.59 - ETA: 20s - loss: 6.60 - ETA: 18s - loss: 6.60 - ETA: 17s - loss: 6.60 - ETA: 16s - loss: 6.61 - ETA: 16s - loss: 6.61 - ETA: 17s - loss: 6.62 - ETA: 17s - loss: 6.61 - ETA: 16s - loss: 6.61 - ETA: 15s - loss: 6.60 - ETA: 14s - loss: 6.60 - ETA: 13s - loss: 6.60 - ETA: 13s - loss: 6.60 - ETA: 12s - loss: 6.60 - ETA: 11s - loss: 6.60 - ETA: 10s - loss: 6.60 - ETA: 9s - loss: 6.6064 - ETA: 8s - loss: 6.609 - ETA: 7s - loss: 6.616 - ETA: 6s - loss: 6.618 - ETA: 5s - loss: 6.622 - ETA: 4s - loss: 6.619 - ETA: 3s - loss: 6.614 - ETA: 2s - loss: 6.618 - ETA: 2s - loss: 6.618 - ETA: 1s - loss: 6.622 - ETA: 0s - loss: 6.6200
# Epoch 00008: val_loss did not improve from 0.69856
# 173076/173076 [==============================] - 51s 297us/sample - loss: 6.6198 - val_loss: 0.7005
# Epoch 9/500
# 171840/173076 [============================>.] - ETA: 39s - loss: 6.64 - ETA: 34s - loss: 6.67 - ETA: 25s - loss: 6.62 - ETA: 21s - loss: 6.67 - ETA: 18s - loss: 6.65 - ETA: 16s - loss: 6.61 - ETA: 15s - loss: 6.60 - ETA: 19s - loss: 6.59 - ETA: 21s - loss: 6.59 - ETA: 21s - loss: 6.58 - ETA: 19s - loss: 6.58 - ETA: 18s - loss: 6.58 - ETA: 19s - loss: 6.59 - ETA: 18s - loss: 6.58 - ETA: 18s - loss: 6.59 - ETA: 17s - loss: 6.58 - ETA: 16s - loss: 6.58 - ETA: 15s - loss: 6.58 - ETA: 15s - loss: 6.57 - ETA: 14s - loss: 6.58 - ETA: 13s - loss: 6.58 - ETA: 13s - loss: 6.58 - ETA: 12s - loss: 6.58 - ETA: 12s - loss: 6.58 - ETA: 11s - loss: 6.59 - ETA: 11s - loss: 6.59 - ETA: 10s - loss: 6.59 - ETA: 9s - loss: 6.6001 - ETA: 8s - loss: 6.605 - ETA: 8s - loss: 6.604 - ETA: 7s - loss: 6.604 - ETA: 6s - loss: 6.609 - ETA: 5s - loss: 6.612 - ETA: 4s - loss: 6.613 - ETA: 4s - loss: 6.615 - ETA: 3s - loss: 6.616 - ETA: 2s - loss: 6.620 - ETA: 1s - loss: 6.619 - ETA: 1s - loss: 6.617 - ETA: 0s - loss: 6.6187
# Epoch 00009: val_loss improved from 0.69856 to 0.69769, saving model to stroke_lstm_model_weights.best.hdf5
# 173076/173076 [==============================] - 50s 291us/sample - loss: 6.6198 - val_loss: 0.6977
# Epoch 10/500
# 171840/173076 [============================>.] - ETA: 1:05 - loss: 6.603 - ETA: 55s - loss: 6.526 - ETA: 51s - loss: 6.57 - ETA: 51s - loss: 6.55 - ETA: 53s - loss: 6.56 - ETA: 54s - loss: 6.56 - ETA: 55s - loss: 6.57 - ETA: 58s - loss: 6.58 - ETA: 55s - loss: 6.58 - ETA: 52s - loss: 6.60 - ETA: 50s - loss: 6.59 - ETA: 45s - loss: 6.60 - ETA: 43s - loss: 6.59 - ETA: 39s - loss: 6.60 - ETA: 37s - loss: 6.61 - ETA: 34s - loss: 6.62 - ETA: 32s - loss: 6.61 - ETA: 30s - loss: 6.60 - ETA: 28s - loss: 6.60 - ETA: 26s - loss: 6.61 - ETA: 24s - loss: 6.61 - ETA: 22s - loss: 6.61 - ETA: 21s - loss: 6.62 - ETA: 19s - loss: 6.63 - ETA: 18s - loss: 6.62 - ETA: 16s - loss: 6.63 - ETA: 15s - loss: 6.63 - ETA: 14s - loss: 6.63 - ETA: 12s - loss: 6.63 - ETA: 11s - loss: 6.63 - ETA: 10s - loss: 6.62 - ETA: 9s - loss: 6.6255 - ETA: 7s - loss: 6.629 - ETA: 6s - loss: 6.622 - ETA: 5s - loss: 6.625 - ETA: 4s - loss: 6.624 - ETA: 3s - loss: 6.626 - ETA: 2s - loss: 6.623 - ETA: 1s - loss: 6.624 - ETA: 0s - loss: 6.6223
# Epoch 00010: val_loss did not improve from 0.69769
# 173076/173076 [==============================] - 58s 337us/sample - loss: 6.6198 - val_loss: 0.7011
# Epoch 11/500
# 171840/173076 [============================>.] - ETA: 1:03 - loss: 6.729 - ETA: 37s - loss: 6.709 - ETA: 27s - loss: 6.73 - ETA: 36s - loss: 6.71 - ETA: 31s - loss: 6.68 - ETA: 30s - loss: 6.68 - ETA: 27s - loss: 6.65 - ETA: 26s - loss: 6.65 - ETA: 25s - loss: 6.63 - ETA: 25s - loss: 6.63 - ETA: 23s - loss: 6.62 - ETA: 23s - loss: 6.60 - ETA: 22s - loss: 6.61 - ETA: 21s - loss: 6.61 - ETA: 20s - loss: 6.60 - ETA: 19s - loss: 6.60 - ETA: 18s - loss: 6.60 - ETA: 18s - loss: 6.61 - ETA: 17s - loss: 6.61 - ETA: 16s - loss: 6.61 - ETA: 16s - loss: 6.61 - ETA: 15s - loss: 6.61 - ETA: 13s - loss: 6.60 - ETA: 13s - loss: 6.60 - ETA: 12s - loss: 6.59 - ETA: 11s - loss: 6.59 - ETA: 10s - loss: 6.59 - ETA: 9s - loss: 6.6015 - ETA: 9s - loss: 6.603 - ETA: 8s - loss: 6.610 - ETA: 7s - loss: 6.605 - ETA: 6s - loss: 6.604 - ETA: 5s - loss: 6.608 - ETA: 4s - loss: 6.610 - ETA: 4s - loss: 6.612 - ETA: 3s - loss: 6.617 - ETA: 2s - loss: 6.618 - ETA: 1s - loss: 6.620 - ETA: 1s - loss: 6.621 - ETA: 0s - loss: 6.6204
# Epoch 00011: val_loss did not improve from 0.69769
# 173076/173076 [==============================] - 49s 281us/sample - loss: 6.6198 - val_loss: 0.6992
# Epoch 12/500
# 171840/173076 [============================>.] - ETA: 52s - loss: 6.76 - ETA: 51s - loss: 6.70 - ETA: 50s - loss: 6.69 - ETA: 51s - loss: 6.66 - ETA: 54s - loss: 6.64 - ETA: 53s - loss: 6.70 - ETA: 53s - loss: 6.65 - ETA: 48s - loss: 6.66 - ETA: 42s - loss: 6.66 - ETA: 39s - loss: 6.65 - ETA: 37s - loss: 6.64 - ETA: 33s - loss: 6.62 - ETA: 31s - loss: 6.61 - ETA: 28s - loss: 6.61 - ETA: 27s - loss: 6.60 - ETA: 27s - loss: 6.60 - ETA: 25s - loss: 6.61 - ETA: 24s - loss: 6.61 - ETA: 22s - loss: 6.60 - ETA: 22s - loss: 6.61 - ETA: 20s - loss: 6.60 - ETA: 19s - loss: 6.60 - ETA: 17s - loss: 6.59 - ETA: 16s - loss: 6.58 - ETA: 15s - loss: 6.59 - ETA: 13s - loss: 6.58 - ETA: 12s - loss: 6.59 - ETA: 11s - loss: 6.60 - ETA: 10s - loss: 6.60 - ETA: 9s - loss: 6.6075 - ETA: 8s - loss: 6.605 - ETA: 7s - loss: 6.605 - ETA: 6s - loss: 6.601 - ETA: 5s - loss: 6.603 - ETA: 4s - loss: 6.608 - ETA: 3s - loss: 6.609 - ETA: 2s - loss: 6.606 - ETA: 2s - loss: 6.613 - ETA: 1s - loss: 6.616 - ETA: 0s - loss: 6.6193
# Epoch 00012: val_loss did not improve from 0.69769
# 173076/173076 [==============================] - 49s 283us/sample - loss: 6.6199 - val_loss: 0.6998
# Epoch 13/500
# 171840/173076 [============================>.] - ETA: 27s - loss: 6.64 - ETA: 26s - loss: 6.59 - ETA: 37s - loss: 6.58 - ETA: 30s - loss: 6.54 - ETA: 31s - loss: 6.52 - ETA: 27s - loss: 6.53 - ETA: 29s - loss: 6.56 - ETA: 26s - loss: 6.55 - ETA: 23s - loss: 6.57 - ETA: 21s - loss: 6.56 - ETA: 19s - loss: 6.57 - ETA: 20s - loss: 6.60 - ETA: 19s - loss: 6.59 - ETA: 19s - loss: 6.59 - ETA: 18s - loss: 6.60 - ETA: 17s - loss: 6.61 - ETA: 16s - loss: 6.60 - ETA: 15s - loss: 6.61 - ETA: 15s - loss: 6.62 - ETA: 14s - loss: 6.62 - ETA: 13s - loss: 6.62 - ETA: 13s - loss: 6.62 - ETA: 12s - loss: 6.63 - ETA: 11s - loss: 6.62 - ETA: 10s - loss: 6.62 - ETA: 10s - loss: 6.63 - ETA: 9s - loss: 6.6283 - ETA: 8s - loss: 6.627 - ETA: 7s - loss: 6.626 - ETA: 7s - loss: 6.626 - ETA: 6s - loss: 6.618 - ETA: 6s - loss: 6.622 - ETA: 5s - loss: 6.621 - ETA: 4s - loss: 6.622 - ETA: 3s - loss: 6.616 - ETA: 3s - loss: 6.622 - ETA: 2s - loss: 6.621 - ETA: 1s - loss: 6.619 - ETA: 0s - loss: 6.619 - ETA: 0s - loss: 6.6198
# Epoch 00013: val_loss did not improve from 0.69769
# 173076/173076 [==============================] - 48s 276us/sample - loss: 6.6198 - val_loss: 0.6981
# Epoch 14/500
# 171840/173076 [============================>.] - ETA: 1:43 - loss: 6.610 - ETA: 1:09 - loss: 6.612 - ETA: 1:02 - loss: 6.683 - ETA: 58s - loss: 6.623 - ETA: 54s - loss: 6.63 - ETA: 52s - loss: 6.64 - ETA: 1:02 - loss: 6.598 - ETA: 58s - loss: 6.598 - ETA: 1:06 - loss: 6.597 - ETA: 1:03 - loss: 6.602 - ETA: 1:01 - loss: 6.601 - ETA: 57s - loss: 6.601 - ETA: 54s - loss: 6.59 - ETA: 52s - loss: 6.60 - ETA: 50s - loss: 6.59 - ETA: 47s - loss: 6.60 - ETA: 43s - loss: 6.60 - ETA: 39s - loss: 6.59 - ETA: 36s - loss: 6.59 - ETA: 33s - loss: 6.60 - ETA: 30s - loss: 6.61 - ETA: 27s - loss: 6.62 - ETA: 25s - loss: 6.62 - ETA: 22s - loss: 6.62 - ETA: 20s - loss: 6.62 - ETA: 18s - loss: 6.61 - ETA: 16s - loss: 6.62 - ETA: 15s - loss: 6.62 - ETA: 13s - loss: 6.62 - ETA: 11s - loss: 6.62 - ETA: 10s - loss: 6.62 - ETA: 9s - loss: 6.6242 - ETA: 7s - loss: 6.618 - ETA: 6s - loss: 6.618 - ETA: 5s - loss: 6.615 - ETA: 4s - loss: 6.623 - ETA: 3s - loss: 6.620 - ETA: 2s - loss: 6.619 - ETA: 1s - loss: 6.617 - ETA: 0s - loss: 6.6190
# Epoch 00014: val_loss did not improve from 0.69769
# 173076/173076 [==============================] - 60s 348us/sample - loss: 6.6199 - val_loss: 0.7005
# Epoch 15/500
# 171840/173076 [============================>.] - ETA: 14s - loss: 6.56 - ETA: 20s - loss: 6.61 - ETA: 29s - loss: 6.67 - ETA: 32s - loss: 6.67 - ETA: 28s - loss: 6.64 - ETA: 28s - loss: 6.64 - ETA: 26s - loss: 6.61 - ETA: 23s - loss: 6.59 - ETA: 24s - loss: 6.59 - ETA: 23s - loss: 6.60 - ETA: 22s - loss: 6.61 - ETA: 21s - loss: 6.61 - ETA: 21s - loss: 6.59 - ETA: 19s - loss: 6.59 - ETA: 19s - loss: 6.58 - ETA: 18s - loss: 6.59 - ETA: 18s - loss: 6.60 - ETA: 16s - loss: 6.61 - ETA: 16s - loss: 6.61 - ETA: 15s - loss: 6.60 - ETA: 14s - loss: 6.60 - ETA: 14s - loss: 6.60 - ETA: 14s - loss: 6.59 - ETA: 13s - loss: 6.60 - ETA: 12s - loss: 6.60 - ETA: 11s - loss: 6.60 - ETA: 10s - loss: 6.60 - ETA: 9s - loss: 6.6122 - ETA: 8s - loss: 6.615 - ETA: 8s - loss: 6.624 - ETA: 7s - loss: 6.630 - ETA: 6s - loss: 6.630 - ETA: 5s - loss: 6.631 - ETA: 4s - loss: 6.626 - ETA: 4s - loss: 6.622 - ETA: 3s - loss: 6.621 - ETA: 2s - loss: 6.623 - ETA: 1s - loss: 6.619 - ETA: 0s - loss: 6.619 - ETA: 0s - loss: 6.6185
# Epoch 00015: val_loss improved from 0.69769 to 0.69573, saving model to stroke_lstm_model_weights.best.hdf5
# 173076/173076 [==============================] - 46s 266us/sample - loss: 6.6198 - val_loss: 0.6957
# Epoch 16/500
# 171840/173076 [============================>.] - ETA: 30s - loss: 6.62 - ETA: 21s - loss: 6.45 - ETA: 21s - loss: 6.51 - ETA: 25s - loss: 6.49 - ETA: 21s - loss: 6.47 - ETA: 19s - loss: 6.52 - ETA: 21s - loss: 6.51 - ETA: 21s - loss: 6.53 - ETA: 19s - loss: 6.56 - ETA: 19s - loss: 6.56 - ETA: 20s - loss: 6.58 - ETA: 18s - loss: 6.57 - ETA: 18s - loss: 6.59 - ETA: 16s - loss: 6.59 - ETA: 17s - loss: 6.58 - ETA: 15s - loss: 6.58 - ETA: 16s - loss: 6.58 - ETA: 15s - loss: 6.58 - ETA: 14s - loss: 6.60 - ETA: 14s - loss: 6.60 - ETA: 13s - loss: 6.61 - ETA: 12s - loss: 6.60 - ETA: 12s - loss: 6.60 - ETA: 11s - loss: 6.60 - ETA: 10s - loss: 6.61 - ETA: 9s - loss: 6.6147 - ETA: 8s - loss: 6.616 - ETA: 8s - loss: 6.616 - ETA: 7s - loss: 6.611 - ETA: 7s - loss: 6.614 - ETA: 6s - loss: 6.621 - ETA: 5s - loss: 6.620 - ETA: 4s - loss: 6.620 - ETA: 4s - loss: 6.619 - ETA: 3s - loss: 6.616 - ETA: 2s - loss: 6.617 - ETA: 2s - loss: 6.617 - ETA: 1s - loss: 6.619 - ETA: 0s - loss: 6.619 - ETA: 0s - loss: 6.6197
# Epoch 00016: val_loss did not improve from 0.69573
# 173076/173076 [==============================] - 42s 245us/sample - loss: 6.6198 - val_loss: 0.6981
# Epoch 17/500
# 171840/173076 [============================>.] - ETA: 1:06 - loss: 6.466 - ETA: 53s - loss: 6.513 - ETA: 51s - loss: 6.50 - ETA: 1:08 - loss: 6.519 - ETA: 1:05 - loss: 6.520 - ETA: 58s - loss: 6.534 - ETA: 54s - loss: 6.54 - ETA: 50s - loss: 6.56 - ETA: 47s - loss: 6.59 - ETA: 42s - loss: 6.60 - ETA: 40s - loss: 6.59 - ETA: 36s - loss: 6.60 - ETA: 33s - loss: 6.59 - ETA: 32s - loss: 6.61 - ETA: 30s - loss: 6.61 - ETA: 28s - loss: 6.61 - ETA: 26s - loss: 6.62 - ETA: 24s - loss: 6.62 - ETA: 22s - loss: 6.61 - ETA: 21s - loss: 6.60 - ETA: 19s - loss: 6.60 - ETA: 18s - loss: 6.60 - ETA: 16s - loss: 6.60 - ETA: 15s - loss: 6.60 - ETA: 14s - loss: 6.59 - ETA: 13s - loss: 6.60 - ETA: 12s - loss: 6.60 - ETA: 11s - loss: 6.60 - ETA: 10s - loss: 6.61 - ETA: 9s - loss: 6.6150 - ETA: 8s - loss: 6.622 - ETA: 7s - loss: 6.627 - ETA: 6s - loss: 6.628 - ETA: 5s - loss: 6.629 - ETA: 4s - loss: 6.623 - ETA: 3s - loss: 6.626 - ETA: 2s - loss: 6.625 - ETA: 1s - loss: 6.626 - ETA: 1s - loss: 6.618 - ETA: 0s - loss: 6.6186
# Epoch 00017: val_loss did not improve from 0.69573
# 173076/173076 [==============================] - 45s 257us/sample - loss: 6.6198 - val_loss: 0.6973
# Epoch 18/500
# 171840/173076 [============================>.] - ETA: 24s - loss: 6.76 - ETA: 17s - loss: 6.73 - ETA: 21s - loss: 6.75 - ETA: 22s - loss: 6.73 - ETA: 20s - loss: 6.71 - ETA: 18s - loss: 6.69 - ETA: 18s - loss: 6.70 - ETA: 20s - loss: 6.68 - ETA: 20s - loss: 6.67 - ETA: 19s - loss: 6.64 - ETA: 18s - loss: 6.65 - ETA: 17s - loss: 6.66 - ETA: 17s - loss: 6.66 - ETA: 16s - loss: 6.65 - ETA: 15s - loss: 6.65 - ETA: 14s - loss: 6.65 - ETA: 15s - loss: 6.63 - ETA: 14s - loss: 6.63 - ETA: 14s - loss: 6.64 - ETA: 13s - loss: 6.64 - ETA: 12s - loss: 6.63 - ETA: 12s - loss: 6.63 - ETA: 11s - loss: 6.63 - ETA: 11s - loss: 6.63 - ETA: 10s - loss: 6.62 - ETA: 9s - loss: 6.6145 - ETA: 8s - loss: 6.617 - ETA: 8s - loss: 6.619 - ETA: 7s - loss: 6.623 - ETA: 6s - loss: 6.619 - ETA: 6s - loss: 6.614 - ETA: 5s - loss: 6.611 - ETA: 4s - loss: 6.611 - ETA: 4s - loss: 6.618 - ETA: 3s - loss: 6.615 - ETA: 2s - loss: 6.619 - ETA: 2s - loss: 6.620 - ETA: 1s - loss: 6.620 - ETA: 0s - loss: 6.618 - ETA: 0s - loss: 6.6188
# Epoch 00018: val_loss improved from 0.69573 to 0.69508, saving model to stroke_lstm_model_weights.best.hdf5
# 173076/173076 [==============================] - 40s 229us/sample - loss: 6.6198 - val_loss: 0.6951
# Epoch 19/500
# 171840/173076 [============================>.] - ETA: 29s - loss: 6.80 - ETA: 29s - loss: 6.65 - ETA: 23s - loss: 6.64 - ETA: 20s - loss: 6.56 - ETA: 18s - loss: 6.57 - ETA: 22s - loss: 6.59 - ETA: 20s - loss: 6.59 - ETA: 18s - loss: 6.58 - ETA: 18s - loss: 6.57 - ETA: 17s - loss: 6.57 - ETA: 18s - loss: 6.59 - ETA: 17s - loss: 6.58 - ETA: 17s - loss: 6.59 - ETA: 16s - loss: 6.61 - ETA: 15s - loss: 6.60 - ETA: 14s - loss: 6.61 - ETA: 13s - loss: 6.61 - ETA: 12s - loss: 6.62 - ETA: 11s - loss: 6.62 - ETA: 10s - loss: 6.63 - ETA: 9s - loss: 6.6399 - ETA: 9s - loss: 6.640 - ETA: 8s - loss: 6.637 - ETA: 7s - loss: 6.625 - ETA: 7s - loss: 6.619 - ETA: 6s - loss: 6.618 - ETA: 5s - loss: 6.621 - ETA: 5s - loss: 6.618 - ETA: 4s - loss: 6.621 - ETA: 4s - loss: 6.615 - ETA: 3s - loss: 6.615 - ETA: 3s - loss: 6.613 - ETA: 2s - loss: 6.611 - ETA: 2s - loss: 6.614 - ETA: 2s - loss: 6.613 - ETA: 1s - loss: 6.614 - ETA: 1s - loss: 6.618 - ETA: 0s - loss: 6.620 - ETA: 0s - loss: 6.620 - ETA: 0s - loss: 6.6186
# Epoch 00019: val_loss did not improve from 0.69508
# 173076/173076 [==============================] - 33s 189us/sample - loss: 6.6197 - val_loss: 0.6965
# Epoch 20/500
# 171840/173076 [============================>.] - ETA: 24s - loss: 6.56 - ETA: 17s - loss: 6.55 - ETA: 20s - loss: 6.50 - ETA: 25s - loss: 6.52 - ETA: 26s - loss: 6.53 - ETA: 23s - loss: 6.54 - ETA: 26s - loss: 6.54 - ETA: 24s - loss: 6.54 - ETA: 23s - loss: 6.56 - ETA: 24s - loss: 6.56 - ETA: 22s - loss: 6.56 - ETA: 21s - loss: 6.57 - ETA: 19s - loss: 6.58 - ETA: 20s - loss: 6.58 - ETA: 18s - loss: 6.59 - ETA: 17s - loss: 6.60 - ETA: 16s - loss: 6.62 - ETA: 15s - loss: 6.62 - ETA: 14s - loss: 6.63 - ETA: 14s - loss: 6.62 - ETA: 13s - loss: 6.63 - ETA: 12s - loss: 6.62 - ETA: 12s - loss: 6.63 - ETA: 11s - loss: 6.62 - ETA: 10s - loss: 6.63 - ETA: 9s - loss: 6.6239 - ETA: 8s - loss: 6.619 - ETA: 8s - loss: 6.621 - ETA: 7s - loss: 6.626 - ETA: 6s - loss: 6.623 - ETA: 6s - loss: 6.632 - ETA: 5s - loss: 6.635 - ETA: 4s - loss: 6.630 - ETA: 4s - loss: 6.628 - ETA: 3s - loss: 6.628 - ETA: 2s - loss: 6.631 - ETA: 2s - loss: 6.630 - ETA: 1s - loss: 6.633 - ETA: 0s - loss: 6.626 - ETA: 0s - loss: 6.6218
# Epoch 00020: val_loss did not improve from 0.69508
# 173076/173076 [==============================] - 37s 211us/sample - loss: 6.6197 - val_loss: 0.6967
# Epoch 21/500
# 171840/173076 [============================>.] - ETA: 17s - loss: 6.31 - ETA: 12s - loss: 6.46 - ETA: 11s - loss: 6.50 - ETA: 10s - loss: 6.54 - ETA: 10s - loss: 6.61 - ETA: 9s - loss: 6.6325 - ETA: 9s - loss: 6.600 - ETA: 8s - loss: 6.608 - ETA: 8s - loss: 6.623 - ETA: 7s - loss: 6.628 - ETA: 7s - loss: 6.625 - ETA: 7s - loss: 6.625 - ETA: 7s - loss: 6.620 - ETA: 6s - loss: 6.621 - ETA: 6s - loss: 6.630 - ETA: 6s - loss: 6.632 - ETA: 5s - loss: 6.633 - ETA: 5s - loss: 6.632 - ETA: 5s - loss: 6.633 - ETA: 4s - loss: 6.644 - ETA: 4s - loss: 6.644 - ETA: 4s - loss: 6.640 - ETA: 4s - loss: 6.637 - ETA: 3s - loss: 6.636 - ETA: 5s - loss: 6.626 - ETA: 5s - loss: 6.619 - ETA: 5s - loss: 6.625 - ETA: 4s - loss: 6.623 - ETA: 4s - loss: 6.628 - ETA: 3s - loss: 6.628 - ETA: 4s - loss: 6.625 - ETA: 4s - loss: 6.621 - ETA: 3s - loss: 6.625 - ETA: 3s - loss: 6.622 - ETA: 2s - loss: 6.620 - ETA: 2s - loss: 6.622 - ETA: 1s - loss: 6.615 - ETA: 1s - loss: 6.617 - ETA: 0s - loss: 6.620 - ETA: 0s - loss: 6.6217
# Epoch 00021: val_loss did not improve from 0.69508
# 173076/173076 [==============================] - 35s 202us/sample - loss: 6.6198 - val_loss: 0.6970
# Epoch 22/500
# 171840/173076 [============================>.] - ETA: 13s - loss: 6.51 - ETA: 19s - loss: 6.57 - ETA: 16s - loss: 6.61 - ETA: 20s - loss: 6.62 - ETA: 29s - loss: 6.65 - ETA: 30s - loss: 6.63 - ETA: 30s - loss: 6.60 - ETA: 33s - loss: 6.61 - ETA: 33s - loss: 6.61 - ETA: 30s - loss: 6.60 - ETA: 30s - loss: 6.61 - ETA: 32s - loss: 6.60 - ETA: 31s - loss: 6.61 - ETA: 30s - loss: 6.63 - ETA: 31s - loss: 6.62 - ETA: 28s - loss: 6.63 - ETA: 25s - loss: 6.64 - ETA: 23s - loss: 6.62 - ETA: 22s - loss: 6.62 - ETA: 21s - loss: 6.62 - ETA: 19s - loss: 6.63 - ETA: 18s - loss: 6.62 - ETA: 16s - loss: 6.61 - ETA: 15s - loss: 6.61 - ETA: 14s - loss: 6.60 - ETA: 12s - loss: 6.61 - ETA: 11s - loss: 6.61 - ETA: 10s - loss: 6.62 - ETA: 9s - loss: 6.6233 - ETA: 8s - loss: 6.628 - ETA: 7s - loss: 6.632 - ETA: 6s - loss: 6.627 - ETA: 6s - loss: 6.618 - ETA: 5s - loss: 6.617 - ETA: 4s - loss: 6.616 - ETA: 3s - loss: 6.612 - ETA: 2s - loss: 6.609 - ETA: 1s - loss: 6.612 - ETA: 1s - loss: 6.614 - ETA: 0s - loss: 6.6215
# Epoch 00022: val_loss did not improve from 0.69508
# 173076/173076 [==============================] - 43s 248us/sample - loss: 6.6198 - val_loss: 0.6974
# Epoch 23/500
# 171840/173076 [============================>.] - ETA: 1:23 - loss: 6.570 - ETA: 46s - loss: 6.592 - ETA: 38s - loss: 6.58 - ETA: 29s - loss: 6.57 - ETA: 24s - loss: 6.58 - ETA: 21s - loss: 6.58 - ETA: 19s - loss: 6.58 - ETA: 17s - loss: 6.58 - ETA: 15s - loss: 6.58 - ETA: 14s - loss: 6.58 - ETA: 13s - loss: 6.57 - ETA: 12s - loss: 6.56 - ETA: 11s - loss: 6.54 - ETA: 11s - loss: 6.55 - ETA: 18s - loss: 6.53 - ETA: 19s - loss: 6.53 - ETA: 17s - loss: 6.54 - ETA: 16s - loss: 6.55 - ETA: 14s - loss: 6.55 - ETA: 13s - loss: 6.55 - ETA: 12s - loss: 6.57 - ETA: 11s - loss: 6.58 - ETA: 10s - loss: 6.59 - ETA: 9s - loss: 6.5960 - ETA: 8s - loss: 6.599 - ETA: 7s - loss: 6.600 - ETA: 7s - loss: 6.592 - ETA: 6s - loss: 6.592 - ETA: 5s - loss: 6.591 - ETA: 5s - loss: 6.600 - ETA: 4s - loss: 6.602 - ETA: 4s - loss: 6.601 - ETA: 3s - loss: 6.605 - ETA: 2s - loss: 6.606 - ETA: 2s - loss: 6.609 - ETA: 1s - loss: 6.613 - ETA: 1s - loss: 6.615 - ETA: 1s - loss: 6.615 - ETA: 0s - loss: 6.614 - ETA: 0s - loss: 6.6195
# Epoch 00023: val_loss did not improve from 0.69508
# 173076/173076 [==============================] - 31s 178us/sample - loss: 6.6198 - val_loss: 0.6959
# Epoch 24/500
# 171840/173076 [============================>.] - ETA: 34s - loss: 6.59 - ETA: 22s - loss: 6.66 - ETA: 20s - loss: 6.64 - ETA: 22s - loss: 6.68 - ETA: 22s - loss: 6.69 - ETA: 20s - loss: 6.66 - ETA: 18s - loss: 6.63 - ETA: 16s - loss: 6.64 - ETA: 14s - loss: 6.63 - ETA: 13s - loss: 6.64 - ETA: 12s - loss: 6.65 - ETA: 11s - loss: 6.66 - ETA: 11s - loss: 6.66 - ETA: 13s - loss: 6.66 - ETA: 12s - loss: 6.66 - ETA: 12s - loss: 6.65 - ETA: 12s - loss: 6.66 - ETA: 11s - loss: 6.65 - ETA: 11s - loss: 6.65 - ETA: 12s - loss: 6.65 - ETA: 11s - loss: 6.64 - ETA: 10s - loss: 6.63 - ETA: 9s - loss: 6.6250 - ETA: 8s - loss: 6.616 - ETA: 8s - loss: 6.620 - ETA: 7s - loss: 6.617 - ETA: 6s - loss: 6.612 - ETA: 6s - loss: 6.614 - ETA: 5s - loss: 6.612 - ETA: 4s - loss: 6.619 - ETA: 4s - loss: 6.622 - ETA: 3s - loss: 6.618 - ETA: 3s - loss: 6.625 - ETA: 2s - loss: 6.626 - ETA: 2s - loss: 6.622 - ETA: 1s - loss: 6.621 - ETA: 1s - loss: 6.625 - ETA: 1s - loss: 6.624 - ETA: 0s - loss: 6.623 - ETA: 0s - loss: 6.6208
# Epoch 00024: val_loss did not improve from 0.69508
# 173076/173076 [==============================] - 30s 172us/sample - loss: 6.6198 - val_loss: 0.6960
# Epoch 25/500
# 171840/173076 [============================>.] - ETA: 12s - loss: 6.55 - ETA: 11s - loss: 6.64 - ETA: 11s - loss: 6.55 - ETA: 18s - loss: 6.58 - ETA: 15s - loss: 6.59 - ETA: 16s - loss: 6.60 - ETA: 16s - loss: 6.59 - ETA: 19s - loss: 6.60 - ETA: 21s - loss: 6.59 - ETA: 19s - loss: 6.59 - ETA: 20s - loss: 6.58 - ETA: 20s - loss: 6.58 - ETA: 19s - loss: 6.58 - ETA: 17s - loss: 6.58 - ETA: 16s - loss: 6.58 - ETA: 15s - loss: 6.57 - ETA: 14s - loss: 6.57 - ETA: 12s - loss: 6.57 - ETA: 11s - loss: 6.56 - ETA: 10s - loss: 6.58 - ETA: 10s - loss: 6.58 - ETA: 9s - loss: 6.5790 - ETA: 8s - loss: 6.589 - ETA: 7s - loss: 6.592 - ETA: 7s - loss: 6.593 - ETA: 6s - loss: 6.590 - ETA: 5s - loss: 6.586 - ETA: 5s - loss: 6.586 - ETA: 4s - loss: 6.591 - ETA: 4s - loss: 6.592 - ETA: 3s - loss: 6.592 - ETA: 3s - loss: 6.588 - ETA: 2s - loss: 6.587 - ETA: 2s - loss: 6.591 - ETA: 2s - loss: 6.599 - ETA: 1s - loss: 6.603 - ETA: 1s - loss: 6.608 - ETA: 0s - loss: 6.611 - ETA: 0s - loss: 6.608 - ETA: 0s - loss: 6.6206
# Epoch 00025: val_loss improved from 0.69508 to 0.69325, saving model to stroke_lstm_model_weights.best.hdf5
# 173076/173076 [==============================] - 27s 154us/sample - loss: 6.6198 - val_loss: 0.6933
# Epoch 26/500
# 171840/173076 [============================>.] - ETA: 28s - loss: 6.72 - ETA: 19s - loss: 6.59 - ETA: 24s - loss: 6.59 - ETA: 26s - loss: 6.64 - ETA: 22s - loss: 6.62 - ETA: 22s - loss: 6.59 - ETA: 26s - loss: 6.58 - ETA: 26s - loss: 6.58 - ETA: 24s - loss: 6.60 - ETA: 21s - loss: 6.59 - ETA: 20s - loss: 6.60 - ETA: 19s - loss: 6.62 - ETA: 18s - loss: 6.62 - ETA: 18s - loss: 6.61 - ETA: 18s - loss: 6.62 - ETA: 17s - loss: 6.61 - ETA: 15s - loss: 6.62 - ETA: 14s - loss: 6.62 - ETA: 13s - loss: 6.61 - ETA: 12s - loss: 6.62 - ETA: 11s - loss: 6.62 - ETA: 10s - loss: 6.62 - ETA: 9s - loss: 6.6197 - ETA: 8s - loss: 6.606 - ETA: 8s - loss: 6.595 - ETA: 7s - loss: 6.601 - ETA: 6s - loss: 6.602 - ETA: 6s - loss: 6.602 - ETA: 5s - loss: 6.603 - ETA: 4s - loss: 6.607 - ETA: 4s - loss: 6.608 - ETA: 3s - loss: 6.611 - ETA: 3s - loss: 6.615 - ETA: 2s - loss: 6.612 - ETA: 2s - loss: 6.614 - ETA: 1s - loss: 6.615 - ETA: 1s - loss: 6.618 - ETA: 0s - loss: 6.616 - ETA: 0s - loss: 6.617 - ETA: 0s - loss: 6.6196
# Epoch 00026: val_loss did not improve from 0.69325
# 173076/173076 [==============================] - 28s 163us/sample - loss: 6.6199 - val_loss: 0.6944
# Epoch 27/500
# 171840/173076 [============================>.] - ETA: 52s - loss: 6.58 - ETA: 30s - loss: 6.69 - ETA: 22s - loss: 6.67 - ETA: 19s - loss: 6.67 - ETA: 17s - loss: 6.68 - ETA: 17s - loss: 6.66 - ETA: 18s - loss: 6.65 - ETA: 20s - loss: 6.64 - ETA: 18s - loss: 6.62 - ETA: 16s - loss: 6.63 - ETA: 15s - loss: 6.61 - ETA: 14s - loss: 6.61 - ETA: 14s - loss: 6.62 - ETA: 13s - loss: 6.62 - ETA: 12s - loss: 6.61 - ETA: 11s - loss: 6.62 - ETA: 10s - loss: 6.61 - ETA: 9s - loss: 6.6106 - ETA: 9s - loss: 6.612 - ETA: 8s - loss: 6.609 - ETA: 7s - loss: 6.609 - ETA: 7s - loss: 6.609 - ETA: 6s - loss: 6.619 - ETA: 6s - loss: 6.618 - ETA: 5s - loss: 6.613 - ETA: 5s - loss: 6.613 - ETA: 4s - loss: 6.608 - ETA: 4s - loss: 6.615 - ETA: 3s - loss: 6.607 - ETA: 3s - loss: 6.604 - ETA: 3s - loss: 6.610 - ETA: 2s - loss: 6.611 - ETA: 2s - loss: 6.612 - ETA: 1s - loss: 6.610 - ETA: 1s - loss: 6.615 - ETA: 1s - loss: 6.608 - ETA: 1s - loss: 6.613 - ETA: 0s - loss: 6.618 - ETA: 0s - loss: 6.620 - ETA: 0s - loss: 6.6213
# Epoch 00027: val_loss did not improve from 0.69325
# 173076/173076 [==============================] - 27s 155us/sample - loss: 6.6198 - val_loss: 0.6939
# Epoch 28/500
# 171840/173076 [============================>.] - ETA: 9s - loss: 6.610 - ETA: 7s - loss: 6.730 - ETA: 7s - loss: 6.732 - ETA: 7s - loss: 6.727 - ETA: 6s - loss: 6.705 - ETA: 6s - loss: 6.698 - ETA: 6s - loss: 6.699 - ETA: 5s - loss: 6.697 - ETA: 5s - loss: 6.703 - ETA: 5s - loss: 6.697 - ETA: 5s - loss: 6.701 - ETA: 5s - loss: 6.704 - ETA: 4s - loss: 6.683 - ETA: 4s - loss: 6.696 - ETA: 4s - loss: 6.689 - ETA: 4s - loss: 6.684 - ETA: 4s - loss: 6.678 - ETA: 4s - loss: 6.674 - ETA: 4s - loss: 6.665 - ETA: 6s - loss: 6.662 - ETA: 6s - loss: 6.656 - ETA: 7s - loss: 6.647 - ETA: 7s - loss: 6.644 - ETA: 7s - loss: 6.644 - ETA: 7s - loss: 6.642 - ETA: 7s - loss: 6.633 - ETA: 6s - loss: 6.633 - ETA: 6s - loss: 6.625 - ETA: 5s - loss: 6.631 - ETA: 4s - loss: 6.639 - ETA: 4s - loss: 6.640 - ETA: 3s - loss: 6.646 - ETA: 3s - loss: 6.640 - ETA: 3s - loss: 6.639 - ETA: 3s - loss: 6.630 - ETA: 2s - loss: 6.625 - ETA: 1s - loss: 6.622 - ETA: 1s - loss: 6.622 - ETA: 0s - loss: 6.621 - ETA: 0s - loss: 6.6200
# Epoch 00028: val_loss did not improve from 0.69325
# 173076/173076 [==============================] - 36s 205us/sample - loss: 6.6198 - val_loss: 0.6940
# Epoch 29/500
# 171840/173076 [============================>.] - ETA: 9s - loss: 6.692 - ETA: 7s - loss: 6.644 - ETA: 7s - loss: 6.627 - ETA: 6s - loss: 6.614 - ETA: 6s - loss: 6.599 - ETA: 6s - loss: 6.570 - ETA: 6s - loss: 6.610 - ETA: 5s - loss: 6.622 - ETA: 5s - loss: 6.615 - ETA: 5s - loss: 6.624 - ETA: 5s - loss: 6.615 - ETA: 5s - loss: 6.615 - ETA: 4s - loss: 6.604 - ETA: 4s - loss: 6.615 - ETA: 4s - loss: 6.620 - ETA: 4s - loss: 6.634 - ETA: 4s - loss: 6.629 - ETA: 3s - loss: 6.630 - ETA: 3s - loss: 6.629 - ETA: 3s - loss: 6.625 - ETA: 6s - loss: 6.623 - ETA: 6s - loss: 6.621 - ETA: 7s - loss: 6.619 - ETA: 7s - loss: 6.620 - ETA: 8s - loss: 6.617 - ETA: 8s - loss: 6.611 - ETA: 8s - loss: 6.610 - ETA: 8s - loss: 6.608 - ETA: 7s - loss: 6.608 - ETA: 6s - loss: 6.607 - ETA: 6s - loss: 6.612 - ETA: 5s - loss: 6.619 - ETA: 4s - loss: 6.622 - ETA: 3s - loss: 6.620 - ETA: 3s - loss: 6.620 - ETA: 2s - loss: 6.626 - ETA: 2s - loss: 6.621 - ETA: 1s - loss: 6.623 - ETA: 0s - loss: 6.622 - ETA: 0s - loss: 6.6189
# Epoch 00029: val_loss did not improve from 0.69325
# 173076/173076 [==============================] - 40s 231us/sample - loss: 6.6198 - val_loss: 0.6959
# Epoch 30/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 6.571 - ETA: 7s - loss: 6.490 - ETA: 7s - loss: 6.541 - ETA: 7s - loss: 6.534 - ETA: 6s - loss: 6.546 - ETA: 6s - loss: 6.554 - ETA: 30s - loss: 6.58 - ETA: 34s - loss: 6.56 - ETA: 33s - loss: 6.55 - ETA: 29s - loss: 6.57 - ETA: 27s - loss: 6.58 - ETA: 27s - loss: 6.60 - ETA: 25s - loss: 6.59 - ETA: 22s - loss: 6.60 - ETA: 20s - loss: 6.61 - ETA: 19s - loss: 6.61 - ETA: 17s - loss: 6.60 - ETA: 16s - loss: 6.61 - ETA: 14s - loss: 6.61 - ETA: 13s - loss: 6.62 - ETA: 12s - loss: 6.61 - ETA: 11s - loss: 6.60 - ETA: 10s - loss: 6.60 - ETA: 9s - loss: 6.6044 - ETA: 8s - loss: 6.599 - ETA: 7s - loss: 6.595 - ETA: 7s - loss: 6.604 - ETA: 6s - loss: 6.606 - ETA: 5s - loss: 6.611 - ETA: 5s - loss: 6.609 - ETA: 4s - loss: 6.607 - ETA: 3s - loss: 6.608 - ETA: 3s - loss: 6.613 - ETA: 3s - loss: 6.618 - ETA: 2s - loss: 6.620 - ETA: 2s - loss: 6.618 - ETA: 1s - loss: 6.616 - ETA: 1s - loss: 6.616 - ETA: 0s - loss: 6.617 - ETA: 0s - loss: 6.6200
# Epoch 00030: val_loss did not improve from 0.69325
# 173076/173076 [==============================] - 39s 227us/sample - loss: 6.6198 - val_loss: 0.6960
# Epoch 31/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 6.836 - ETA: 7s - loss: 6.763 - ETA: 7s - loss: 6.669 - ETA: 6s - loss: 6.668 - ETA: 6s - loss: 6.660 - ETA: 6s - loss: 6.651 - ETA: 6s - loss: 6.671 - ETA: 5s - loss: 6.657 - ETA: 5s - loss: 6.656 - ETA: 5s - loss: 6.650 - ETA: 5s - loss: 6.628 - ETA: 5s - loss: 6.620 - ETA: 4s - loss: 6.632 - ETA: 5s - loss: 6.634 - ETA: 4s - loss: 6.644 - ETA: 4s - loss: 6.646 - ETA: 4s - loss: 6.653 - ETA: 4s - loss: 6.652 - ETA: 4s - loss: 6.643 - ETA: 3s - loss: 6.646 - ETA: 9s - loss: 6.638 - ETA: 9s - loss: 6.635 - ETA: 11s - loss: 6.63 - ETA: 11s - loss: 6.62 - ETA: 11s - loss: 6.62 - ETA: 10s - loss: 6.61 - ETA: 9s - loss: 6.6147 - ETA: 8s - loss: 6.619 - ETA: 7s - loss: 6.623 - ETA: 6s - loss: 6.623 - ETA: 5s - loss: 6.624 - ETA: 5s - loss: 6.623 - ETA: 4s - loss: 6.625 - ETA: 3s - loss: 6.625 - ETA: 3s - loss: 6.627 - ETA: 2s - loss: 6.626 - ETA: 1s - loss: 6.623 - ETA: 1s - loss: 6.622 - ETA: 0s - loss: 6.619 - ETA: 0s - loss: 6.6190
# Epoch 00031: val_loss did not improve from 0.69325
# 173076/173076 [==============================] - 36s 207us/sample - loss: 6.6198 - val_loss: 0.6939
# Epoch 32/500
# 171840/173076 [============================>.] - ETA: 9s - loss: 6.822 - ETA: 8s - loss: 6.736 - ETA: 7s - loss: 6.658 - ETA: 7s - loss: 6.675 - ETA: 6s - loss: 6.639 - ETA: 6s - loss: 6.631 - ETA: 6s - loss: 6.618 - ETA: 5s - loss: 6.652 - ETA: 5s - loss: 6.654 - ETA: 5s - loss: 6.657 - ETA: 5s - loss: 6.653 - ETA: 5s - loss: 6.623 - ETA: 4s - loss: 6.619 - ETA: 4s - loss: 6.633 - ETA: 4s - loss: 6.625 - ETA: 4s - loss: 6.626 - ETA: 4s - loss: 6.625 - ETA: 3s - loss: 6.627 - ETA: 3s - loss: 6.630 - ETA: 3s - loss: 6.631 - ETA: 6s - loss: 6.631 - ETA: 6s - loss: 6.635 - ETA: 5s - loss: 6.642 - ETA: 9s - loss: 6.645 - ETA: 9s - loss: 6.641 - ETA: 9s - loss: 6.637 - ETA: 8s - loss: 6.638 - ETA: 8s - loss: 6.644 - ETA: 8s - loss: 6.636 - ETA: 7s - loss: 6.631 - ETA: 6s - loss: 6.629 - ETA: 5s - loss: 6.623 - ETA: 4s - loss: 6.623 - ETA: 4s - loss: 6.621 - ETA: 3s - loss: 6.620 - ETA: 2s - loss: 6.619 - ETA: 1s - loss: 6.619 - ETA: 1s - loss: 6.621 - ETA: 0s - loss: 6.623 - ETA: 0s - loss: 6.6204
# Epoch 00032: val_loss did not improve from 0.69325
# 173076/173076 [==============================] - 37s 212us/sample - loss: 6.6197 - val_loss: 0.6951
# Epoch 33/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 6.674 - ETA: 7s - loss: 6.570 - ETA: 7s - loss: 6.556 - ETA: 6s - loss: 6.605 - ETA: 6s - loss: 6.592 - ETA: 6s - loss: 6.577 - ETA: 6s - loss: 6.606 - ETA: 5s - loss: 6.617 - ETA: 5s - loss: 6.615 - ETA: 5s - loss: 6.614 - ETA: 5s - loss: 6.599 - ETA: 5s - loss: 6.594 - ETA: 4s - loss: 6.599 - ETA: 4s - loss: 6.601 - ETA: 4s - loss: 6.592 - ETA: 4s - loss: 6.583 - ETA: 4s - loss: 6.587 - ETA: 3s - loss: 6.593 - ETA: 3s - loss: 6.601 - ETA: 3s - loss: 6.604 - ETA: 3s - loss: 6.600 - ETA: 3s - loss: 6.606 - ETA: 12s - loss: 6.60 - ETA: 11s - loss: 6.60 - ETA: 10s - loss: 6.59 - ETA: 9s - loss: 6.5963 - ETA: 8s - loss: 6.600 - ETA: 8s - loss: 6.598 - ETA: 7s - loss: 6.598 - ETA: 6s - loss: 6.596 - ETA: 5s - loss: 6.593 - ETA: 4s - loss: 6.598 - ETA: 4s - loss: 6.596 - ETA: 3s - loss: 6.603 - ETA: 2s - loss: 6.608 - ETA: 2s - loss: 6.612 - ETA: 1s - loss: 6.615 - ETA: 1s - loss: 6.613 - ETA: 0s - loss: 6.613 - ETA: 0s - loss: 6.6181
# Epoch 00033: val_loss did not improve from 0.69325
# 173076/173076 [==============================] - 33s 193us/sample - loss: 6.6197 - val_loss: 0.6947
# Epoch 34/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 6.660 - ETA: 8s - loss: 6.635 - ETA: 7s - loss: 6.659 - ETA: 7s - loss: 6.681 - ETA: 6s - loss: 6.670 - ETA: 6s - loss: 6.618 - ETA: 6s - loss: 6.611 - ETA: 6s - loss: 6.636 - ETA: 5s - loss: 6.643 - ETA: 5s - loss: 6.635 - ETA: 5s - loss: 6.628 - ETA: 5s - loss: 6.628 - ETA: 4s - loss: 6.638 - ETA: 4s - loss: 6.630 - ETA: 4s - loss: 6.628 - ETA: 4s - loss: 6.626 - ETA: 4s - loss: 6.633 - ETA: 4s - loss: 6.626 - ETA: 3s - loss: 6.626 - ETA: 3s - loss: 6.633 - ETA: 3s - loss: 6.630 - ETA: 3s - loss: 6.625 - ETA: 3s - loss: 6.624 - ETA: 9s - loss: 6.629 - ETA: 8s - loss: 6.625 - ETA: 8s - loss: 6.630 - ETA: 7s - loss: 6.631 - ETA: 6s - loss: 6.634 - ETA: 6s - loss: 6.638 - ETA: 5s - loss: 6.639 - ETA: 4s - loss: 6.633 - ETA: 4s - loss: 6.623 - ETA: 3s - loss: 6.624 - ETA: 3s - loss: 6.624 - ETA: 2s - loss: 6.627 - ETA: 2s - loss: 6.627 - ETA: 1s - loss: 6.624 - ETA: 1s - loss: 6.622 - ETA: 0s - loss: 6.618 - ETA: 0s - loss: 6.6192
# Epoch 00034: val_loss did not improve from 0.69325
# 173076/173076 [==============================] - 33s 190us/sample - loss: 6.6198 - val_loss: 0.6951
# Epoch 35/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 6.656 - ETA: 7s - loss: 6.685 - ETA: 6s - loss: 6.631 - ETA: 6s - loss: 6.658 - ETA: 6s - loss: 6.622 - ETA: 6s - loss: 6.615 - ETA: 6s - loss: 6.619 - ETA: 5s - loss: 6.625 - ETA: 5s - loss: 6.618 - ETA: 5s - loss: 6.618 - ETA: 5s - loss: 6.625 - ETA: 5s - loss: 6.622 - ETA: 5s - loss: 6.626 - ETA: 4s - loss: 6.627 - ETA: 4s - loss: 6.625 - ETA: 4s - loss: 6.625 - ETA: 7s - loss: 6.626 - ETA: 6s - loss: 6.633 - ETA: 6s - loss: 6.623 - ETA: 5s - loss: 6.625 - ETA: 5s - loss: 6.616 - ETA: 5s - loss: 6.619 - ETA: 6s - loss: 6.620 - ETA: 6s - loss: 6.623 - ETA: 6s - loss: 6.622 - ETA: 8s - loss: 6.615 - ETA: 8s - loss: 6.617 - ETA: 7s - loss: 6.619 - ETA: 7s - loss: 6.619 - ETA: 6s - loss: 6.618 - ETA: 5s - loss: 6.620 - ETA: 4s - loss: 6.622 - ETA: 4s - loss: 6.623 - ETA: 3s - loss: 6.617 - ETA: 2s - loss: 6.622 - ETA: 2s - loss: 6.623 - ETA: 1s - loss: 6.624 - ETA: 1s - loss: 6.626 - ETA: 0s - loss: 6.624 - ETA: 0s - loss: 6.6200
# Epoch 00035: val_loss did not improve from 0.69325
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.007999999821186066.
# 173076/173076 [==============================] - 33s 193us/sample - loss: 6.6198 - val_loss: 0.6941
# Epoch 36/500
# 171840/173076 [============================>.] - ETA: 9s - loss: 6.509 - ETA: 7s - loss: 6.491 - ETA: 7s - loss: 6.531 - ETA: 6s - loss: 6.552 - ETA: 6s - loss: 6.583 - ETA: 6s - loss: 6.587 - ETA: 6s - loss: 6.596 - ETA: 6s - loss: 6.596 - ETA: 5s - loss: 6.582 - ETA: 5s - loss: 6.571 - ETA: 5s - loss: 6.562 - ETA: 5s - loss: 6.586 - ETA: 5s - loss: 6.592 - ETA: 4s - loss: 6.601 - ETA: 4s - loss: 6.612 - ETA: 4s - loss: 6.598 - ETA: 4s - loss: 6.610 - ETA: 4s - loss: 6.613 - ETA: 3s - loss: 6.612 - ETA: 3s - loss: 6.610 - ETA: 3s - loss: 6.611 - ETA: 8s - loss: 6.608 - ETA: 8s - loss: 6.620 - ETA: 8s - loss: 6.619 - ETA: 8s - loss: 6.615 - ETA: 8s - loss: 6.614 - ETA: 8s - loss: 6.611 - ETA: 7s - loss: 6.613 - ETA: 7s - loss: 6.606 - ETA: 6s - loss: 6.610 - ETA: 5s - loss: 6.612 - ETA: 5s - loss: 6.610 - ETA: 4s - loss: 6.610 - ETA: 3s - loss: 6.608 - ETA: 2s - loss: 6.606 - ETA: 2s - loss: 6.612 - ETA: 1s - loss: 6.612 - ETA: 1s - loss: 6.617 - ETA: 0s - loss: 6.619 - ETA: 0s - loss: 6.6219
# Epoch 00036: val_loss did not improve from 0.69325
# 173076/173076 [==============================] - 33s 193us/sample - loss: 6.6198 - val_loss: 0.6934
# Epoch 37/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 6.685 - ETA: 7s - loss: 6.576 - ETA: 7s - loss: 6.588 - ETA: 6s - loss: 6.603 - ETA: 6s - loss: 6.613 - ETA: 6s - loss: 6.621 - ETA: 6s - loss: 6.632 - ETA: 5s - loss: 6.639 - ETA: 5s - loss: 6.620 - ETA: 5s - loss: 6.641 - ETA: 5s - loss: 6.625 - ETA: 5s - loss: 6.628 - ETA: 5s - loss: 6.621 - ETA: 4s - loss: 6.623 - ETA: 4s - loss: 6.618 - ETA: 4s - loss: 6.612 - ETA: 4s - loss: 6.628 - ETA: 4s - loss: 6.618 - ETA: 3s - loss: 6.606 - ETA: 3s - loss: 6.600 - ETA: 10s - loss: 6.58 - ETA: 10s - loss: 6.58 - ETA: 10s - loss: 6.58 - ETA: 10s - loss: 6.58 - ETA: 10s - loss: 6.58 - ETA: 9s - loss: 6.5986 - ETA: 8s - loss: 6.603 - ETA: 7s - loss: 6.608 - ETA: 6s - loss: 6.601 - ETA: 6s - loss: 6.600 - ETA: 5s - loss: 6.603 - ETA: 4s - loss: 6.602 - ETA: 4s - loss: 6.610 - ETA: 3s - loss: 6.612 - ETA: 2s - loss: 6.612 - ETA: 2s - loss: 6.615 - ETA: 1s - loss: 6.617 - ETA: 1s - loss: 6.619 - ETA: 0s - loss: 6.616 - ETA: 0s - loss: 6.6192
# Epoch 00037: val_loss improved from 0.69325 to 0.69310, saving model to stroke_lstm_model_weights.best.hdf5
# 173076/173076 [==============================] - 33s 189us/sample - loss: 6.6198 - val_loss: 0.6931
# Epoch 38/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 6.621 - ETA: 8s - loss: 6.572 - ETA: 7s - loss: 6.651 - ETA: 7s - loss: 6.652 - ETA: 6s - loss: 6.585 - ETA: 6s - loss: 6.566 - ETA: 6s - loss: 6.549 - ETA: 6s - loss: 6.530 - ETA: 5s - loss: 6.557 - ETA: 5s - loss: 6.559 - ETA: 6s - loss: 6.573 - ETA: 5s - loss: 6.571 - ETA: 5s - loss: 6.564 - ETA: 5s - loss: 6.580 - ETA: 5s - loss: 6.595 - ETA: 4s - loss: 6.597 - ETA: 4s - loss: 6.587 - ETA: 4s - loss: 6.602 - ETA: 4s - loss: 6.600 - ETA: 3s - loss: 6.602 - ETA: 3s - loss: 6.600 - ETA: 3s - loss: 6.603 - ETA: 3s - loss: 6.603 - ETA: 7s - loss: 6.602 - ETA: 7s - loss: 6.615 - ETA: 7s - loss: 6.612 - ETA: 6s - loss: 6.617 - ETA: 6s - loss: 6.621 - ETA: 6s - loss: 6.623 - ETA: 6s - loss: 6.622 - ETA: 5s - loss: 6.625 - ETA: 5s - loss: 6.621 - ETA: 4s - loss: 6.618 - ETA: 3s - loss: 6.615 - ETA: 3s - loss: 6.616 - ETA: 2s - loss: 6.619 - ETA: 1s - loss: 6.620 - ETA: 1s - loss: 6.621 - ETA: 0s - loss: 6.620 - ETA: 0s - loss: 6.6205
# Epoch 00038: val_loss did not improve from 0.69310
# 173076/173076 [==============================] - 35s 204us/sample - loss: 6.6198 - val_loss: 0.6938
# Epoch 39/500
# 171840/173076 [============================>.] - ETA: 9s - loss: 6.596 - ETA: 12s - loss: 6.65 - ETA: 10s - loss: 6.62 - ETA: 9s - loss: 6.5914 - ETA: 8s - loss: 6.631 - ETA: 7s - loss: 6.630 - ETA: 7s - loss: 6.640 - ETA: 6s - loss: 6.640 - ETA: 6s - loss: 6.633 - ETA: 6s - loss: 6.648 - ETA: 5s - loss: 6.652 - ETA: 5s - loss: 6.645 - ETA: 5s - loss: 6.643 - ETA: 5s - loss: 6.639 - ETA: 4s - loss: 6.640 - ETA: 4s - loss: 6.639 - ETA: 4s - loss: 6.628 - ETA: 4s - loss: 6.620 - ETA: 4s - loss: 6.611 - ETA: 3s - loss: 6.605 - ETA: 8s - loss: 6.602 - ETA: 9s - loss: 6.604 - ETA: 9s - loss: 6.607 - ETA: 9s - loss: 6.607 - ETA: 9s - loss: 6.606 - ETA: 8s - loss: 6.602 - ETA: 7s - loss: 6.593 - ETA: 7s - loss: 6.591 - ETA: 6s - loss: 6.592 - ETA: 6s - loss: 6.594 - ETA: 5s - loss: 6.599 - ETA: 4s - loss: 6.602 - ETA: 4s - loss: 6.605 - ETA: 3s - loss: 6.603 - ETA: 2s - loss: 6.609 - ETA: 2s - loss: 6.612 - ETA: 1s - loss: 6.610 - ETA: 1s - loss: 6.611 - ETA: 0s - loss: 6.617 - ETA: 0s - loss: 6.6212
# Epoch 00039: val_loss did not improve from 0.69310
# 173076/173076 [==============================] - 34s 196us/sample - loss: 6.6199 - val_loss: 0.6953
# Epoch 40/500
# ...
# Epoch 00054: val_loss did not improve from 0.69310
# 173076/173076 [==============================] - 52s 298us/sample - loss: 9.9251 - val_loss: 16.1181
# Epoch 55/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 9.882 - ETA: 7s - loss: 9.935 - ETA: 6s - loss: 9.896 - ETA: 6s - loss: 9.899 - ETA: 6s - loss: 9.924 - ETA: 6s - loss: 9.930 - ETA: 5s - loss: 9.916 - ETA: 5s - loss: 9.912 - ETA: 5s - loss: 9.925 - ETA: 5s - loss: 9.945 - ETA: 5s - loss: 9.936 - ETA: 5s - loss: 9.949 - ETA: 4s - loss: 9.954 - ETA: 9s - loss: 9.946 - ETA: 11s - loss: 9.93 - ETA: 11s - loss: 9.93 - ETA: 13s - loss: 9.94 - ETA: 13s - loss: 9.93 - ETA: 13s - loss: 9.93 - ETA: 20s - loss: 9.93 - ETA: 18s - loss: 9.93 - ETA: 17s - loss: 9.92 - ETA: 15s - loss: 9.92 - ETA: 14s - loss: 9.91 - ETA: 12s - loss: 9.91 - ETA: 11s - loss: 9.91 - ETA: 10s - loss: 9.91 - ETA: 9s - loss: 9.9160 - ETA: 8s - loss: 9.915 - ETA: 7s - loss: 9.911 - ETA: 6s - loss: 9.916 - ETA: 5s - loss: 9.911 - ETA: 5s - loss: 9.909 - ETA: 4s - loss: 9.911 - ETA: 3s - loss: 9.915 - ETA: 2s - loss: 9.919 - ETA: 2s - loss: 9.924 - ETA: 1s - loss: 9.922 - ETA: 0s - loss: 9.923 - ETA: 0s - loss: 9.9252
# Epoch 00055: val_loss did not improve from 0.69310
# 173076/173076 [==============================] - 51s 296us/sample - loss: 9.9251 - val_loss: 16.1181
# Epoch 56/500
# 171840/173076 [============================>.] - ETA: 9s - loss: 9.912 - ETA: 8s - loss: 9.878 - ETA: 7s - loss: 9.814 - ETA: 7s - loss: 9.883 - ETA: 6s - loss: 9.899 - ETA: 6s - loss: 9.886 - ETA: 7s - loss: 9.895 - ETA: 7s - loss: 9.905 - ETA: 6s - loss: 9.912 - ETA: 6s - loss: 9.914 - ETA: 6s - loss: 9.922 - ETA: 5s - loss: 9.919 - ETA: 14s - loss: 9.91 - ETA: 15s - loss: 9.92 - ETA: 16s - loss: 9.91 - ETA: 17s - loss: 9.92 - ETA: 16s - loss: 9.91 - ETA: 26s - loss: 9.90 - ETA: 24s - loss: 9.90 - ETA: 22s - loss: 9.90 - ETA: 20s - loss: 9.89 - ETA: 18s - loss: 9.89 - ETA: 17s - loss: 9.89 - ETA: 15s - loss: 9.89 - ETA: 14s - loss: 9.90 - ETA: 13s - loss: 9.90 - ETA: 11s - loss: 9.91 - ETA: 10s - loss: 9.90 - ETA: 9s - loss: 9.9058 - ETA: 8s - loss: 9.910 - ETA: 7s - loss: 9.917 - ETA: 6s - loss: 9.917 - ETA: 6s - loss: 9.925 - ETA: 5s - loss: 9.923 - ETA: 5s - loss: 9.921 - ETA: 4s - loss: 9.920 - ETA: 3s - loss: 9.923 - ETA: 2s - loss: 9.927 - ETA: 1s - loss: 9.928 - ETA: 0s - loss: 9.9278
# Epoch 00056: val_loss did not improve from 0.69310
# 173076/173076 [==============================] - 67s 385us/sample - loss: 9.9251 - val_loss: 16.1181
# Epoch 57/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 9.781 - ETA: 7s - loss: 9.766 - ETA: 7s - loss: 9.822 - ETA: 6s - loss: 9.892 - ETA: 6s - loss: 9.911 - ETA: 6s - loss: 9.937 - ETA: 5s - loss: 9.948 - ETA: 5s - loss: 9.949 - ETA: 5s - loss: 9.949 - ETA: 9s - loss: 9.964 - ETA: 14s - loss: 9.96 - ETA: 17s - loss: 9.94 - ETA: 17s - loss: 9.93 - ETA: 18s - loss: 9.93 - ETA: 17s - loss: 9.93 - ETA: 15s - loss: 9.94 - ETA: 15s - loss: 9.94 - ETA: 13s - loss: 9.93 - ETA: 12s - loss: 9.93 - ETA: 22s - loss: 9.93 - ETA: 20s - loss: 9.92 - ETA: 18s - loss: 9.93 - ETA: 17s - loss: 9.92 - ETA: 15s - loss: 9.92 - ETA: 14s - loss: 9.92 - ETA: 12s - loss: 9.92 - ETA: 11s - loss: 9.92 - ETA: 10s - loss: 9.92 - ETA: 9s - loss: 9.9263 - ETA: 8s - loss: 9.927 - ETA: 8s - loss: 9.931 - ETA: 7s - loss: 9.928 - ETA: 6s - loss: 9.924 - ETA: 5s - loss: 9.924 - ETA: 4s - loss: 9.925 - ETA: 3s - loss: 9.926 - ETA: 2s - loss: 9.921 - ETA: 1s - loss: 9.922 - ETA: 1s - loss: 9.922 - ETA: 0s - loss: 9.9242
# Epoch 00057: val_loss did not improve from 0.69310
# 173076/173076 [==============================] - 76s 438us/sample - loss: 9.9251 - val_loss: 16.1181
# Epoch 58/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 9.769 - ETA: 7s - loss: 9.732 - ETA: 6s - loss: 9.772 - ETA: 6s - loss: 9.807 - ETA: 6s - loss: 9.824 - ETA: 6s - loss: 9.844 - ETA: 5s - loss: 9.855 - ETA: 5s - loss: 9.842 - ETA: 5s - loss: 9.829 - ETA: 5s - loss: 9.843 - ETA: 7s - loss: 9.861 - ETA: 15s - loss: 9.85 - ETA: 18s - loss: 9.86 - ETA: 17s - loss: 9.86 - ETA: 29s - loss: 9.86 - ETA: 29s - loss: 9.87 - ETA: 26s - loss: 9.87 - ETA: 24s - loss: 9.89 - ETA: 22s - loss: 9.89 - ETA: 20s - loss: 9.90 - ETA: 18s - loss: 9.90 - ETA: 17s - loss: 9.91 - ETA: 15s - loss: 9.90 - ETA: 14s - loss: 9.90 - ETA: 12s - loss: 9.90 - ETA: 13s - loss: 9.90 - ETA: 12s - loss: 9.90 - ETA: 11s - loss: 9.91 - ETA: 10s - loss: 9.91 - ETA: 9s - loss: 9.9177 - ETA: 8s - loss: 9.917 - ETA: 7s - loss: 9.915 - ETA: 6s - loss: 9.918 - ETA: 5s - loss: 9.917 - ETA: 4s - loss: 9.920 - ETA: 3s - loss: 9.921 - ETA: 2s - loss: 9.922 - ETA: 2s - loss: 9.924 - ETA: 1s - loss: 9.924 - ETA: 0s - loss: 9.9249
# Epoch 00058: val_loss did not improve from 0.69310
# 173076/173076 [==============================] - 109s 630us/sample - loss: 9.9251 - val_loss: 16.1181
# Epoch 59/500
# 171840/173076 [============================>.] - ETA: 2:26 - loss: 9.732 - ETA: 1:45 - loss: 9.888 - ETA: 1:19 - loss: 9.946 - ETA: 1:13 - loss: 9.905 - ETA: 1:09 - loss: 9.947 - ETA: 1:17 - loss: 9.924 - ETA: 1:10 - loss: 9.910 - ETA: 1:06 - loss: 9.903 - ETA: 1:02 - loss: 9.886 - ETA: 55s - loss: 9.921 - ETA: 54s - loss: 9.92 - ETA: 52s - loss: 9.93 - ETA: 49s - loss: 9.93 - ETA: 46s - loss: 9.94 - ETA: 42s - loss: 9.94 - ETA: 38s - loss: 9.94 - ETA: 34s - loss: 9.95 - ETA: 31s - loss: 9.94 - ETA: 28s - loss: 9.93 - ETA: 26s - loss: 9.93 - ETA: 23s - loss: 9.94 - ETA: 21s - loss: 9.94 - ETA: 19s - loss: 9.94 - ETA: 18s - loss: 9.93 - ETA: 16s - loss: 9.93 - ETA: 14s - loss: 9.93 - ETA: 13s - loss: 9.92 - ETA: 12s - loss: 9.92 - ETA: 10s - loss: 9.92 - ETA: 9s - loss: 9.9294 - ETA: 9s - loss: 9.935 - ETA: 8s - loss: 9.931 - ETA: 7s - loss: 9.928 - ETA: 6s - loss: 9.929 - ETA: 5s - loss: 9.929 - ETA: 4s - loss: 9.932 - ETA: 3s - loss: 9.931 - ETA: 2s - loss: 9.931 - ETA: 1s - loss: 9.926 - ETA: 0s - loss: 9.9263
# Epoch 00059: val_loss did not improve from 0.69310
# 173076/173076 [==============================] - 76s 438us/sample - loss: 9.9251 - val_loss: 16.1181
# Epoch 60/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 10.04 - ETA: 7s - loss: 9.9162 - ETA: 7s - loss: 9.967 - ETA: 7s - loss: 9.993 - ETA: 7s - loss: 10.00 - ETA: 6s - loss: 9.9694 - ETA: 6s - loss: 9.961 - ETA: 6s - loss: 9.956 - ETA: 6s - loss: 9.960 - ETA: 5s - loss: 9.948 - ETA: 5s - loss: 9.950 - ETA: 5s - loss: 9.954 - ETA: 7s - loss: 9.938 - ETA: 7s - loss: 9.932 - ETA: 9s - loss: 9.929 - ETA: 10s - loss: 9.93 - ETA: 9s - loss: 9.9350 - ETA: 9s - loss: 9.922 - ETA: 11s - loss: 9.92 - ETA: 14s - loss: 9.92 - ETA: 16s - loss: 9.93 - ETA: 17s - loss: 9.93 - ETA: 15s - loss: 9.93 - ETA: 14s - loss: 9.93 - ETA: 13s - loss: 9.93 - ETA: 11s - loss: 9.93 - ETA: 10s - loss: 9.92 - ETA: 9s - loss: 9.9241 - ETA: 8s - loss: 9.926 - ETA: 7s - loss: 9.926 - ETA: 6s - loss: 9.932 - ETA: 5s - loss: 9.933 - ETA: 5s - loss: 9.927 - ETA: 4s - loss: 9.924 - ETA: 3s - loss: 9.919 - ETA: 2s - loss: 9.921 - ETA: 2s - loss: 9.919 - ETA: 1s - loss: 9.924 - ETA: 1s - loss: 9.926 - ETA: 0s - loss: 9.9244
# Epoch 00060: val_loss did not improve from 0.69310
# 173076/173076 [==============================] - 69s 399us/sample - loss: 9.9251 - val_loss: 16.1181
# Epoch 61/500
# 171840/173076 [============================>.] - ETA: 7s - loss: 9.829 - ETA: 6s - loss: 9.850 - ETA: 6s - loss: 9.848 - ETA: 6s - loss: 9.914 - ETA: 6s - loss: 9.902 - ETA: 6s - loss: 9.923 - ETA: 6s - loss: 9.910 - ETA: 5s - loss: 9.912 - ETA: 5s - loss: 9.953 - ETA: 5s - loss: 9.934 - ETA: 5s - loss: 9.942 - ETA: 5s - loss: 9.944 - ETA: 5s - loss: 9.939 - ETA: 9s - loss: 9.927 - ETA: 11s - loss: 9.92 - ETA: 13s - loss: 9.92 - ETA: 12s - loss: 9.92 - ETA: 11s - loss: 9.92 - ETA: 21s - loss: 9.92 - ETA: 19s - loss: 9.92 - ETA: 17s - loss: 9.91 - ETA: 16s - loss: 9.92 - ETA: 14s - loss: 9.91 - ETA: 13s - loss: 9.91 - ETA: 12s - loss: 9.91 - ETA: 11s - loss: 9.92 - ETA: 10s - loss: 9.92 - ETA: 9s - loss: 9.9255 - ETA: 8s - loss: 9.926 - ETA: 7s - loss: 9.921 - ETA: 6s - loss: 9.918 - ETA: 5s - loss: 9.916 - ETA: 4s - loss: 9.918 - ETA: 4s - loss: 9.918 - ETA: 3s - loss: 9.921 - ETA: 2s - loss: 9.924 - ETA: 1s - loss: 9.924 - ETA: 1s - loss: 9.920 - ETA: 0s - loss: 9.925 - ETA: 0s - loss: 9.9239
# Epoch 00061: val_loss did not improve from 0.69310
# 173076/173076 [==============================] - 45s 261us/sample - loss: 9.9251 - val_loss: 16.1181
# Epoch 62/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 10.02 - ETA: 7s - loss: 10.01 - ETA: 7s - loss: 9.9325 - ETA: 6s - loss: 9.909 - ETA: 6s - loss: 9.953 - ETA: 6s - loss: 9.945 - ETA: 6s - loss: 9.943 - ETA: 6s - loss: 9.946 - ETA: 5s - loss: 9.921 - ETA: 5s - loss: 9.903 - ETA: 5s - loss: 9.922 - ETA: 13s - loss: 9.91 - ETA: 13s - loss: 9.90 - ETA: 12s - loss: 9.90 - ETA: 12s - loss: 9.89 - ETA: 12s - loss: 9.88 - ETA: 11s - loss: 9.89 - ETA: 14s - loss: 9.89 - ETA: 22s - loss: 9.90 - ETA: 21s - loss: 9.90 - ETA: 19s - loss: 9.89 - ETA: 21s - loss: 9.91 - ETA: 19s - loss: 9.92 - ETA: 18s - loss: 9.91 - ETA: 16s - loss: 9.91 - ETA: 14s - loss: 9.91 - ETA: 13s - loss: 9.91 - ETA: 11s - loss: 9.90 - ETA: 10s - loss: 9.91 - ETA: 9s - loss: 9.9141 - ETA: 8s - loss: 9.912 - ETA: 7s - loss: 9.912 - ETA: 6s - loss: 9.915 - ETA: 5s - loss: 9.916 - ETA: 4s - loss: 9.920 - ETA: 3s - loss: 9.917 - ETA: 2s - loss: 9.914 - ETA: 2s - loss: 9.917 - ETA: 1s - loss: 9.919 - ETA: 0s - loss: 9.9246
# Epoch 00062: val_loss did not improve from 0.69310
# 173076/173076 [==============================] - 49s 281us/sample - loss: 9.9251 - val_loss: 16.1181
# Epoch 63/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 10.00 - ETA: 7s - loss: 10.00 - ETA: 7s - loss: 9.9913 - ETA: 7s - loss: 9.965 - ETA: 7s - loss: 9.944 - ETA: 7s - loss: 9.936 - ETA: 6s - loss: 9.928 - ETA: 6s - loss: 9.943 - ETA: 6s - loss: 9.955 - ETA: 6s - loss: 9.929 - ETA: 5s - loss: 9.923 - ETA: 5s - loss: 9.943 - ETA: 5s - loss: 9.938 - ETA: 5s - loss: 9.931 - ETA: 4s - loss: 9.932 - ETA: 4s - loss: 9.946 - ETA: 4s - loss: 9.937 - ETA: 4s - loss: 9.940 - ETA: 4s - loss: 9.932 - ETA: 3s - loss: 9.930 - ETA: 3s - loss: 9.939 - ETA: 4s - loss: 9.925 - ETA: 5s - loss: 9.927 - ETA: 9s - loss: 9.922 - ETA: 8s - loss: 9.929 - ETA: 9s - loss: 9.935 - ETA: 8s - loss: 9.927 - ETA: 7s - loss: 9.919 - ETA: 8s - loss: 9.915 - ETA: 7s - loss: 9.921 - ETA: 6s - loss: 9.923 - ETA: 5s - loss: 9.920 - ETA: 4s - loss: 9.927 - ETA: 4s - loss: 9.931 - ETA: 3s - loss: 9.929 - ETA: 2s - loss: 9.928 - ETA: 2s - loss: 9.930 - ETA: 1s - loss: 9.925 - ETA: 0s - loss: 9.925 - ETA: 0s - loss: 9.9250
# Epoch 00063: val_loss did not improve from 0.69310
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.0051199994981288915.
# 173076/173076 [==============================] - 41s 235us/sample - loss: 9.9251 - val_loss: 16.1181
# Epoch 64/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 10.05 - ETA: 7s - loss: 9.9050 - ETA: 7s - loss: 9.935 - ETA: 6s - loss: 9.913 - ETA: 6s - loss: 9.918 - ETA: 6s - loss: 9.928 - ETA: 6s - loss: 9.922 - ETA: 6s - loss: 9.917 - ETA: 5s - loss: 9.880 - ETA: 5s - loss: 9.881 - ETA: 5s - loss: 9.893 - ETA: 5s - loss: 9.895 - ETA: 5s - loss: 9.883 - ETA: 4s - loss: 9.891 - ETA: 4s - loss: 9.905 - ETA: 4s - loss: 9.906 - ETA: 4s - loss: 9.913 - ETA: 4s - loss: 9.911 - ETA: 5s - loss: 9.919 - ETA: 5s - loss: 9.930 - ETA: 5s - loss: 9.925 - ETA: 6s - loss: 9.929 - ETA: 15s - loss: 9.92 - ETA: 15s - loss: 9.92 - ETA: 13s - loss: 9.93 - ETA: 12s - loss: 9.93 - ETA: 11s - loss: 9.93 - ETA: 10s - loss: 9.93 - ETA: 9s - loss: 9.9321 - ETA: 8s - loss: 9.926 - ETA: 7s - loss: 9.927 - ETA: 6s - loss: 9.930 - ETA: 5s - loss: 9.931 - ETA: 4s - loss: 9.929 - ETA: 3s - loss: 9.924 - ETA: 2s - loss: 9.923 - ETA: 2s - loss: 9.924 - ETA: 1s - loss: 9.927 - ETA: 0s - loss: 9.924 - ETA: 0s - loss: 9.9240
# Epoch 00064: val_loss did not improve from 0.69310
# 173076/173076 [==============================] - 46s 268us/sample - loss: 9.9251 - val_loss: 16.1181
# Epoch 65/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 9.927 - ETA: 7s - loss: 9.936 - ETA: 7s - loss: 9.938 - ETA: 7s - loss: 9.943 - ETA: 7s - loss: 9.983 - ETA: 6s - loss: 9.958 - ETA: 6s - loss: 9.945 - ETA: 6s - loss: 9.946 - ETA: 6s - loss: 9.933 - ETA: 5s - loss: 9.914 - ETA: 5s - loss: 9.921 - ETA: 5s - loss: 9.925 - ETA: 5s - loss: 9.940 - ETA: 5s - loss: 9.932 - ETA: 4s - loss: 9.943 - ETA: 4s - loss: 9.930 - ETA: 4s - loss: 9.932 - ETA: 5s - loss: 9.936 - ETA: 5s - loss: 9.933 - ETA: 6s - loss: 9.933 - ETA: 5s - loss: 9.937 - ETA: 5s - loss: 9.927 - ETA: 12s - loss: 9.92 - ETA: 11s - loss: 9.91 - ETA: 10s - loss: 9.91 - ETA: 10s - loss: 9.92 - ETA: 10s - loss: 9.92 - ETA: 9s - loss: 9.9192 - ETA: 8s - loss: 9.930 - ETA: 7s - loss: 9.930 - ETA: 6s - loss: 9.931 - ETA: 5s - loss: 9.928 - ETA: 4s - loss: 9.927 - ETA: 4s - loss: 9.928 - ETA: 3s - loss: 9.930 - ETA: 2s - loss: 9.932 - ETA: 2s - loss: 9.930 - ETA: 1s - loss: 9.923 - ETA: 0s - loss: 9.922 - ETA: 0s - loss: 9.9253
# Epoch 00065: val_loss did not improve from 0.69310
# 173076/173076 [==============================] - 51s 293us/sample - loss: 9.9251 - val_loss: 16.1181
# Epoch 66/500
# 171840/173076 [============================>.] - ETA: 8s - loss: 9.807 - ETA: 8s - loss: 9.875 - ETA: 7s - loss: 9.903 - ETA: 7s - loss: 9.929 - ETA: 7s - loss: 9.957 - ETA: 7s - loss: 9.968 - ETA: 7s - loss: 9.969 - ETA: 6s - loss: 9.966 - ETA: 6s - loss: 9.961 - ETA: 6s - loss: 9.936 - ETA: 6s - loss: 9.940 - ETA: 6s - loss: 9.937 - ETA: 5s - loss: 9.952 - ETA: 5s - loss: 9.952 - ETA: 5s - loss: 9.966 - ETA: 5s - loss: 9.961 - ETA: 5s - loss: 9.950 - ETA: 8s - loss: 9.945 - ETA: 7s - loss: 9.933 - ETA: 7s - loss: 9.926 - ETA: 7s - loss: 9.923 - ETA: 6s - loss: 9.926 - ETA: 8s - loss: 9.923 - ETA: 8s - loss: 9.919 - ETA: 13s - loss: 9.92 - ETA: 12s - loss: 9.92 - ETA: 11s - loss: 9.92 - ETA: 10s - loss: 9.92 - ETA: 9s - loss: 9.9244 - ETA: 8s - loss: 9.924 - ETA: 7s - loss: 9.927 - ETA: 7s - loss: 9.927 - ETA: 6s - loss: 9.929 - ETA: 5s - loss: 9.928 - ETA: 4s - loss: 9.927 - ETA: 3s - loss: 9.920 - ETA: 2s - loss: 9.915 - ETA: 1s - loss: 9.921 - ETA: 0s - loss: 9.922 - ETA: 0s - loss: 9.9247
# Epoch 00066: val_loss did not improve from 0.69310
# 173076/173076 [==============================] - 37s 214us/sample - loss: 9.9251 - val_loss: 16.1181
# Epoch 67/500
# 171840/173076 [============================>.] - ETA: 12s - loss: 9.89 - ETA: 11s - loss: 9.88 - ETA: 11s - loss: 9.91 - ETA: 10s - loss: 9.88 - ETA: 10s - loss: 9.85 - ETA: 9s - loss: 9.8906 - ETA: 9s - loss: 9.898 - ETA: 9s - loss: 9.909 - ETA: 8s - loss: 9.910 - ETA: 7s - loss: 9.892 - ETA: 7s - loss: 9.911 - ETA: 7s - loss: 9.932 - ETA: 6s - loss: 9.922 - ETA: 6s - loss: 9.924 - ETA: 6s - loss: 9.930 - ETA: 9s - loss: 9.923 - ETA: 9s - loss: 9.921 - ETA: 9s - loss: 9.920 - ETA: 8s - loss: 9.916 - ETA: 11s - loss: 9.91 - ETA: 12s - loss: 9.90 - ETA: 12s - loss: 9.91 - ETA: 12s - loss: 9.91 - ETA: 11s - loss: 9.91 - ETA: 10s - loss: 9.91 - ETA: 9s - loss: 9.9089 - ETA: 9s - loss: 9.907 - ETA: 9s - loss: 9.913 - ETA: 8s - loss: 9.915 - ETA: 7s - loss: 9.913 - ETA: 6s - loss: 9.913 - ETA: 5s - loss: 9.912 - ETA: 5s - loss: 9.916 - ETA: 4s - loss: 9.920 - ETA: 3s - loss: 9.921 - ETA: 2s - loss: 9.917 - ETA: 2s - loss: 9.919 - ETA: 1s - loss: 9.924 - ETA: 0s - loss: 9.926 - ETA: 0s - loss: 9.9251
# Epoch 00067: val_loss did not improve from 0.69310
# 173076/173076 [==============================] - 122s 703us/sample - loss: 9.9251 - val_loss: 16.1181

# %%
model.load_weights(weight_path)
lstm_results = model.evaluate(test_X, test_y, batch_size = 4096)
print('Accuracy: %2.1f%%, Top 3 Accuracy %2.1f%%, Recall S %2.8f%%, Recall L %2.8f%%, Precision S %2.8f%%, Precision L %2.8f%%' % (100*lstm_results[1], 100*lstm_results[2], lstm_results[3], lstm_results[4], lstm_results[5], lstm_results[6]))
# Out:
# 69938/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
#  - 3s 44us/sample - loss: 0.6933
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-a78040134e51> in <module>
#       1 model.load_weights(weight_path)
#       2 lstm_results = model.evaluate(test_X, test_y, batch_size = 4096)
# ----> 3 print('Accuracy: %2.1f%%, Top 3 Accuracy %2.1f%%, Recall S %2.8f%%, Recall L %2.8f%%, Precision S %2.8f%%, Precision L %2.8f%%' % (100*lstm_results[1], 100*lstm_results[2], lstm_results[3], lstm_results[4], lstm_results[5], lstm_results[6]))
#
# IndexError: invalid index to scalar variable.

# %%
import gc
del train_gen
del valid_gen
del X_train
del y_train
del train_df
gc.collect()

# %%
model.save_weights('./trained_model.h5', overwrite=True)

# %% [markdown]
# Load and normalize the test data

# %%
def load_test(ts_length = 150000):
    base_dir = 'input/test/'
    test_files = [f for f in listdir(base_dir) if isfile(join(base_dir, f))]

    ts = np.empty([len(test_files), ts_length])
    ids = []
    
    i = 0
    for f in tqdm_notebook(test_files):
        ids.append(splitext(f)[0])
        t_df = pd.read_csv(base_dir + f, dtype={"acoustic_data": np.int8})
        ts[i, :] = t_df['acoustic_data'].values
        i = i + 1

    return ts, ids

# %%
test_data, test_ids = load_test()

# %%
X_test = test_data
X_test = np.expand_dims(X_test, 2)
X_test.shape

# %% [markdown]
# Load best model and predict

# %%
y_pred = model.predict(X_test)

# %%
submission_df = pd.DataFrame({'seg_id': test_ids, 'time_to_failure': y_pred[:, 0]})

# %%
submission_df.to_csv("submission.csv", index=False)

# %% [markdown]
# <a href="submission.csv"> Download File </a>

# %%
lb.transform([-1, 0, 1])
