# %%
xfile = 'F:\workspace\j6stock\XOpenHighLowCloseVol_tp10_cl10.txt'
lstm_size = 120         # 3 times the amount of channels
lstm_layers = 2        # Number of layers
batch_size = 2048       # Batch size
learning_rate = 0.001  #0.0001  # Learning rate (default is 0.001)
epochs = 10

# Fixed
#amount_of_features_cvs = 5 # cvs with prefix with feature column
#n_channels = amount_of_features
seq_len = lstm_size
y_column = 6
compute_val_at = 0

# %%
import tensorflow as tf
from sklearn import preprocessing
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt2
import pandas as pd
from pandas import datetime
import math, time
import itertools
from sklearn import preprocessing
import datetime
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
from keras.models import load_model
import keras
import pandas_datareader.data as web
import h5py
import os
from keras import backend as K
# Out:
# Using Theano backend.
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# C:\Users\lai\Anaconda3\lib\site-packages\theano\configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
def get_stock_data(normalize=True, ma=[]):
    """
    Return a dataframe of that stock and normalize all the values. 
    (Optional: create moving average)
    """
    df = pd.read_csv(filepath_or_buffer  = xfile )
    #TODO Use previous close instead of open
    df['change'] = df['close'] - df['open']
    for i, row in df.iterrows():
        df.at[i, 'high'] = df.at[i, 'high'] - (df.at[i, 'open'] if df.at[i, 'open'] > df.at[i, 'close'] else df.at[i, 'close'])
        df.at[i, 'low'] = (df.at[i, 'close'] if df.at[i, 'close'] < df.at[i, 'open'] else df.at[i, 'open']) - df.at[i, 'low']
    df.dropna(inplace=True)
    df = df.drop('open', axis=1)
    # Moving Average    
    if ma != []:
        for moving in ma:
            df['{}ma'.format(moving)] = df['close'].rolling(window=moving).mean()
    df.dropna(inplace=True)
    if normalize:
        min_max_scaler = preprocessing.MinMaxScaler()
        #df['open'] = min_max_scaler.fit_transform(df.open.values.reshape(-1,1))
        df['high'] = min_max_scaler.fit_transform(df.high.values.reshape(-1,1))
        df['low'] = min_max_scaler.fit_transform(df.low.values.reshape(-1,1))
        #df['vol'] = min_max_scaler.fit_transform(df.vol.values.reshape(-1,1))
        df['close'] = min_max_scaler.fit_transform(df['close'].values.reshape(-1,1))
        #df['change'] = min_max_scaler.fit_transform(df['change'].values.reshape(-1,1))
        if ma != []:
            for moving in ma:
                df['{}ma'.format(moving)] = min_max_scaler.fit_transform(df['{}ma'.format(moving)].values.reshape(-1,1))  
    df.dropna(inplace=True)
               
    # Move y_result to the rightmost for the ease of training
    adj_close = df['y_result']
    df.drop(labels=['y_result'], axis=1, inplace=True)
    df = pd.concat([df, adj_close], axis=1)
      
    return df

# %%
df = get_stock_data( ma=[50, 100, 200])
amount_of_features = len(df.columns)-1

# %%
def plot_stock(df):
    print(df.head())
    plt.subplot(211)
    plt.plot(df['close'], color='red', label='Close')
    plt.legend(loc='best')
    plt.subplot(212)
    plt.plot(df['change'], color='blue', label='Percentage change')
    plt.legend(loc='best')
    fig, (ax1, ax2) = plt.subplots(1, 2)
    ax1.plot(df['high'], color='red', label='high')
    ax1.legend(loc='best')
 
    ax2.plot(df['low'], color='red', label='low')
    ax2.legend(loc='best')
    plt.show()

# %%
plot_stock(df)
# Out:
#              high           low     close    change      50ma     100ma  \
# 199  4.445337e-14  6.182380e-03  0.357085 -0.000150  0.351429  0.351070
# 200  2.002002e-03  1.545595e-02  0.356606 -0.000060  0.351433  0.351063
# 201  1.301301e-02  7.727975e-03  0.356893  0.000035  0.351445  0.351060
# 202  4.445337e-14  1.545595e-03  0.357133  0.000015  0.351502  0.351082
# 203  6.006006e-03  6.863821e-14  0.358138  0.000095  0.351587  0.351141
#
#         200ma  y_result
# 199  0.346428         0
# 200  0.346426         0
# 201  0.346424         0
# 202  0.346433         0
# 203  0.346448         0

# %%
corr = df.corr()
ax = sns.heatmap(corr, cmap="YlGnBu")
plt.show()

# %%
def load_data(stock, seq_len):
    print ("Amount of features = {}".format(amount_of_features))
    data = stock.as_matrix()
    sequence_length = seq_len + 1 # index starting from 0
    x_result = []
    y_result = []
    for index in range(seq_len, len(data) ): # maxmimum date = lastest date - sequence length
        x_result.append(data[index-seq_len: index,:-1]) # index : index + 22days
        y_result.append(data[index ,amount_of_features]);

    #print('---', data[0])
    #print('---', x_result[0])
    #print('---', y_result[0])
    x_result = np.array(x_result)
    y_result = np.array(y_result)
    row = round(0.6 * y_result.shape[0]) # 80% split
    print ("Amount of training data = {}".format(0.9 * x_result.shape[0]))
    print ("Amount of testing data = {}".format(0.1 * y_result.shape[0]))
     
    X_train = x_result[:int(row), :] # 90% date
    y_train = y_result[:int(row)] # 90% date
        

    X_test = x_result[int(row):, :]
    y_test = y_result[int(row):]
    # filter for 1 and -1 for validation only
    X_test = X_test[y_test[:]!=0,:]
    y_test = y_test[y_test[:]!=0]
    #print(result.shape[0], len(y_result), int(row), y_result[int(row):])
    #X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], amount_of_features-1))
    #X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], amount_of_features-1))
    
    return [X_train, y_train, X_test, y_test]

# %%
lb = preprocessing.LabelBinarizer()
lb.fit([1, 0, -1])

X_tr, lab_tr, X_vld, lab_vld = load_data(df, seq_len)
y_tr = lb.transform(lab_tr)
y_vld = lb.transform(lab_vld)
print(X_tr.shape, lab_tr.shape, X_vld.shape, lab_vld.shape)
print(amount_of_features)
# Out:
# Amount of features = 7
# Amount of training data = 261918.9
# Amount of testing data = 29102.100000000002
# (174613, 120, 7) (174613,) (70626, 120, 7) (70626,)
# 7

# %%
def get_batches(X, y, batch_size = 100):
	""" Return a generator for batches """
	n_batches = len(X) // batch_size
	X, y = X[:n_batches*batch_size], y[:n_batches*batch_size]

	# Loop over batches and yield
	for b in range(0, len(X), batch_size):
		yield X[b:b+batch_size], y[b:b+batch_size]

# %%
graph = tf.Graph()
n_channels = amount_of_features
n_classes = lb.transform([1]).shape[1]
# Construct placeholders
with graph.as_default():
    inputs_ = tf.placeholder(tf.float32, [None, seq_len, n_channels], name = 'inputs')
    labels_ = tf.placeholder(tf.float32, [None, n_classes], name = 'labels')
    keep_prob_ = tf.placeholder(tf.float32, name = 'keep')
    learning_rate_ = tf.placeholder(tf.float32, name = 'learning_rate')

# %% [markdown]
# Construct inputs to LSTM

# %%
with graph.as_default():
    # Construct the LSTM inputs and LSTM cells
    lstm_in = tf.transpose(inputs_, [1,0,2]) # reshape into (seq_len, N, channels)
    lstm_in = tf.reshape(lstm_in, [-1, n_channels]) # Now (seq_len*N, n_channels)
    
    # To cells
    lstm_in = tf.layers.dense(lstm_in, lstm_size, activation=None) # or tf.nn.relu, tf.nn.sigmoid, tf.nn.tanh?
    
    # Open up the tensor into a list of seq_len pieces
    lstm_in = tf.split(lstm_in, seq_len, 0)
    
    # Add LSTM layers
    lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
    drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob_)
    cell = tf.contrib.rnn.MultiRNNCell([drop] * lstm_layers)
    initial_state = cell.zero_state(batch_size, tf.float32)

# %% [markdown]
# Define forward pass, cost function and optimizer:

# %%
with graph.as_default():
    outputs, final_state = tf.contrib.rnn.static_rnn(cell, lstm_in, dtype=tf.float32,
                                                     initial_state = initial_state)
    
    # We only need the last output tensor to pass into a classifier
    logits = tf.layers.dense(outputs[-1], n_classes, name='logits')
    
    # Cost function and optimizer
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels_))
    #optimizer = tf.train.AdamOptimizer(learning_rate_).minimize(cost) # No grad clipping
    
    # Grad clipping
    train_op = tf.train.AdamOptimizer(learning_rate_)

    gradients = train_op.compute_gradients(cost)
    capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients]
    optimizer = train_op.apply_gradients(capped_gradients)
    
    # Accuracy
    correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(labels_, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

# %%
if (os.path.exists('checkpoints') == False):
    # !mkdir checkpoints

# %%
interation_compute_val = 40
validation_acc = []
validation_loss = []

train_acc = []
train_loss = []

with graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    iteration = 1
    saver.restore(sess, "checkpoints/har-lstm.ckpt")
    for e in range(epochs):
        # Initialize 
        state = sess.run(initial_state)
        
        # Loop over batches
        for x,y in get_batches(X_tr, y_tr, batch_size):
            
            # Feed dictionary
            feed = {inputs_ : x, labels_ : y, keep_prob_ : 0.5, 
                    initial_state : state, learning_rate_ : learning_rate}
            
            loss, _ , state, acc = sess.run([cost, optimizer, final_state, accuracy], 
                                             feed_dict = feed)
            train_acc.append(acc)
            train_loss.append(loss)
            
            # Print at each 5 iters
            if (iteration % 5 == 0):
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {:d}".format(iteration),
                      "Train loss: {:6f}".format(loss),
                      "Train acc: {:.6f}".format(acc))
            
            # Compute validation loss at every 25 iterations
            if (iteration%interation_compute_val == compute_val_at):
                
                # Initiate for validation set
                val_state = sess.run(cell.zero_state(batch_size, tf.float32))
                
                val_acc_ = []
                val_loss_ = []
                for x_v, y_v in get_batches(X_vld, y_vld, batch_size):
                    # Feed
                    feed = {inputs_ : x_v, labels_ : y_v, keep_prob_ : 1.0, initial_state : val_state}
                    
                    # Loss
                    loss_v, state_v, acc_v = sess.run([cost, final_state, accuracy], feed_dict = feed)
                    
                    val_acc_.append(acc_v)
                    val_loss_.append(loss_v)
                
                # Print info
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {:d}".format(iteration),
                      "Validation loss: {:6f}".format(np.mean(val_loss_)),
                      "Validation acc: {:.6f}".format(np.mean(val_acc_)))
                
                # Store
                validation_acc.append(np.mean(val_acc_))
                validation_loss.append(np.mean(val_loss_))
            
            # Iterate 
            iteration += 1
    
    saver.save(sess,"checkpoints/har-lstm.ckpt")
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/har-lstm.ckpt
# Epoch: 0/10 Iteration: 5 Train loss: 0.740956 Train acc: 0.693359
# Epoch: 0/10 Iteration: 10 Train loss: 0.665970 Train acc: 0.744629
# Epoch: 0/10 Iteration: 15 Train loss: 0.712659 Train acc: 0.703613
# Epoch: 0/10 Iteration: 20 Train loss: 0.592225 Train acc: 0.770020
# Epoch: 0/10 Iteration: 25 Train loss: 0.757209 Train acc: 0.692871
# Epoch: 0/10 Iteration: 30 Train loss: 0.501100 Train acc: 0.787109
# Epoch: 0/10 Iteration: 35 Train loss: 0.380097 Train acc: 0.856445
# Epoch: 0/10 Iteration: 40 Train loss: 0.512628 Train acc: 0.777832
# Epoch: 0/10 Iteration: 40 Validation loss: 1.478325 Validation acc: 0.347728
# Epoch: 0/10 Iteration: 45 Train loss: 0.586971 Train acc: 0.763672
# Epoch: 0/10 Iteration: 50 Train loss: 0.491148 Train acc: 0.836426
# Epoch: 0/10 Iteration: 55 Train loss: 0.656917 Train acc: 0.724609
# Epoch: 0/10 Iteration: 60 Train loss: 0.848841 Train acc: 0.657227
# Epoch: 0/10 Iteration: 65 Train loss: 0.704514 Train acc: 0.708984
# Epoch: 0/10 Iteration: 70 Train loss: 0.751844 Train acc: 0.665527
# Epoch: 0/10 Iteration: 75 Train loss: 0.775899 Train acc: 0.611328
# Epoch: 0/10 Iteration: 80 Train loss: 0.737607 Train acc: 0.675293
# Epoch: 0/10 Iteration: 80 Validation loss: 1.600326 Validation acc: 0.372774
# Epoch: 0/10 Iteration: 85 Train loss: 0.786554 Train acc: 0.613770
# Epoch: 1/10 Iteration: 90 Train loss: 0.735328 Train acc: 0.697266
# Epoch: 1/10 Iteration: 95 Train loss: 0.681045 Train acc: 0.725586
# Epoch: 1/10 Iteration: 100 Train loss: 0.705249 Train acc: 0.708984
# Epoch: 1/10 Iteration: 105 Train loss: 0.583504 Train acc: 0.764160
# Epoch: 1/10 Iteration: 110 Train loss: 0.701253 Train acc: 0.711914
# Epoch: 1/10 Iteration: 115 Train loss: 0.510163 Train acc: 0.790527
# Epoch: 1/10 Iteration: 120 Train loss: 0.381573 Train acc: 0.854004
# Epoch: 1/10 Iteration: 120 Validation loss: 1.601486 Validation acc: 0.354837
# Epoch: 1/10 Iteration: 125 Train loss: 0.512457 Train acc: 0.776855
# Epoch: 1/10 Iteration: 130 Train loss: 0.614796 Train acc: 0.735840
# Epoch: 1/10 Iteration: 135 Train loss: 0.525892 Train acc: 0.827148
# Epoch: 1/10 Iteration: 140 Train loss: 0.655423 Train acc: 0.723145
# Epoch: 1/10 Iteration: 145 Train loss: 0.771885 Train acc: 0.676270
# Epoch: 1/10 Iteration: 150 Train loss: 0.737500 Train acc: 0.676270
# Epoch: 1/10 Iteration: 155 Train loss: 0.728187 Train acc: 0.686523
# Epoch: 1/10 Iteration: 160 Train loss: 0.791584 Train acc: 0.596680
# Epoch: 1/10 Iteration: 160 Validation loss: 1.490909 Validation acc: 0.385886
# Epoch: 1/10 Iteration: 165 Train loss: 0.706766 Train acc: 0.687988
# Epoch: 1/10 Iteration: 170 Train loss: 0.788327 Train acc: 0.608887
# Epoch: 2/10 Iteration: 175 Train loss: 0.752599 Train acc: 0.686523
# Epoch: 2/10 Iteration: 180 Train loss: 0.662596 Train acc: 0.734375
# Epoch: 2/10 Iteration: 185 Train loss: 0.674504 Train acc: 0.705078
# Epoch: 2/10 Iteration: 190 Train loss: 0.565874 Train acc: 0.779785
# Epoch: 2/10 Iteration: 195 Train loss: 0.690663 Train acc: 0.721191
# Epoch: 2/10 Iteration: 200 Train loss: 0.510487 Train acc: 0.789062
# Epoch: 2/10 Iteration: 200 Validation loss: 1.699778 Validation acc: 0.361500
# Epoch: 2/10 Iteration: 205 Train loss: 0.369147 Train acc: 0.861328
# Epoch: 2/10 Iteration: 210 Train loss: 0.557495 Train acc: 0.768555
# Epoch: 2/10 Iteration: 215 Train loss: 0.620406 Train acc: 0.744141
# Epoch: 2/10 Iteration: 220 Train loss: 0.486816 Train acc: 0.837402
# Epoch: 2/10 Iteration: 225 Train loss: 0.671581 Train acc: 0.719727
# Epoch: 2/10 Iteration: 230 Train loss: 0.817264 Train acc: 0.659180
# Epoch: 2/10 Iteration: 235 Train loss: 0.720880 Train acc: 0.689453
# Epoch: 2/10 Iteration: 240 Train loss: 0.728467 Train acc: 0.681641
# Epoch: 2/10 Iteration: 240 Validation loss: 1.671710 Validation acc: 0.347929
# Epoch: 2/10 Iteration: 245 Train loss: 0.886450 Train acc: 0.541016
# Epoch: 2/10 Iteration: 250 Train loss: 0.711375 Train acc: 0.676270
# Epoch: 2/10 Iteration: 255 Train loss: 0.719082 Train acc: 0.658691
# Epoch: 3/10 Iteration: 260 Train loss: 0.755268 Train acc: 0.690918
# Epoch: 3/10 Iteration: 265 Train loss: 0.672811 Train acc: 0.727051
# Epoch: 3/10 Iteration: 270 Train loss: 0.676924 Train acc: 0.711426
# Epoch: 3/10 Iteration: 275 Train loss: 0.595913 Train acc: 0.769043
# Epoch: 3/10 Iteration: 280 Train loss: 0.662467 Train acc: 0.727539
# Epoch: 3/10 Iteration: 280 Validation loss: 1.693950 Validation acc: 0.334013
# Epoch: 3/10 Iteration: 285 Train loss: 0.493576 Train acc: 0.792969
# Epoch: 3/10 Iteration: 290 Train loss: 0.354128 Train acc: 0.872559
# Epoch: 3/10 Iteration: 295 Train loss: 0.495289 Train acc: 0.791992
# Epoch: 3/10 Iteration: 300 Train loss: 0.582312 Train acc: 0.755859
# Epoch: 3/10 Iteration: 305 Train loss: 0.514281 Train acc: 0.829590
# Epoch: 3/10 Iteration: 310 Train loss: 0.668812 Train acc: 0.719238
# Epoch: 3/10 Iteration: 315 Train loss: 0.790119 Train acc: 0.666016
# Epoch: 3/10 Iteration: 320 Train loss: 0.709877 Train acc: 0.682129
# Epoch: 3/10 Iteration: 320 Validation loss: 1.701060 Validation acc: 0.326732
# Epoch: 3/10 Iteration: 325 Train loss: 0.756983 Train acc: 0.665527
# Epoch: 3/10 Iteration: 330 Train loss: 0.807664 Train acc: 0.593262
# Epoch: 3/10 Iteration: 335 Train loss: 0.705371 Train acc: 0.689941
# Epoch: 3/10 Iteration: 340 Train loss: 0.767307 Train acc: 0.624023
# Epoch: 4/10 Iteration: 345 Train loss: 0.702581 Train acc: 0.712891
# Epoch: 4/10 Iteration: 350 Train loss: 0.658675 Train acc: 0.737793
# Epoch: 4/10 Iteration: 355 Train loss: 0.709504 Train acc: 0.710938
# Epoch: 4/10 Iteration: 360 Train loss: 0.583151 Train acc: 0.776855
# Epoch: 4/10 Iteration: 360 Validation loss: 1.714824 Validation acc: 0.357580
# Epoch: 4/10 Iteration: 365 Train loss: 0.645781 Train acc: 0.738281
# Epoch: 4/10 Iteration: 370 Train loss: 0.513591 Train acc: 0.793457
# Epoch: 4/10 Iteration: 375 Train loss: 0.378094 Train acc: 0.862305
# Epoch: 4/10 Iteration: 380 Train loss: 0.535558 Train acc: 0.785156
# Epoch: 4/10 Iteration: 385 Train loss: 0.615063 Train acc: 0.733887
# Epoch: 4/10 Iteration: 390 Train loss: 0.517743 Train acc: 0.823730
# Epoch: 4/10 Iteration: 395 Train loss: 0.680176 Train acc: 0.710938
# Epoch: 4/10 Iteration: 400 Train loss: 0.878805 Train acc: 0.624512
# Epoch: 4/10 Iteration: 400 Validation loss: 1.772754 Validation acc: 0.376393
# Epoch: 4/10 Iteration: 405 Train loss: 0.715113 Train acc: 0.691895
# Epoch: 4/10 Iteration: 410 Train loss: 0.759950 Train acc: 0.676758
# Epoch: 4/10 Iteration: 415 Train loss: 0.826775 Train acc: 0.578125
# Epoch: 4/10 Iteration: 420 Train loss: 0.708541 Train acc: 0.711914
# Epoch: 4/10 Iteration: 425 Train loss: 0.799998 Train acc: 0.604004
# Epoch: 5/10 Iteration: 430 Train loss: 0.724045 Train acc: 0.715820
# Epoch: 5/10 Iteration: 435 Train loss: 0.695406 Train acc: 0.716797
# Epoch: 5/10 Iteration: 440 Train loss: 0.689076 Train acc: 0.710938
# Epoch: 5/10 Iteration: 440 Validation loss: 1.644329 Validation acc: 0.367805
# Epoch: 5/10 Iteration: 445 Train loss: 0.590616 Train acc: 0.770508
# Epoch: 5/10 Iteration: 450 Train loss: 0.645980 Train acc: 0.732910
# Epoch: 5/10 Iteration: 455 Train loss: 0.477839 Train acc: 0.811035
# Epoch: 5/10 Iteration: 460 Train loss: 0.385088 Train acc: 0.851562
# Epoch: 5/10 Iteration: 465 Train loss: 0.539356 Train acc: 0.768555
# Epoch: 5/10 Iteration: 470 Train loss: 0.630166 Train acc: 0.731934
# Epoch: 5/10 Iteration: 475 Train loss: 0.483885 Train acc: 0.851074
# Epoch: 5/10 Iteration: 480 Train loss: 0.691682 Train acc: 0.707520
# Epoch: 5/10 Iteration: 480 Validation loss: 1.652043 Validation acc: 0.390553
# Epoch: 5/10 Iteration: 485 Train loss: 0.804022 Train acc: 0.654297
# Epoch: 5/10 Iteration: 490 Train loss: 0.763699 Train acc: 0.651367
# Epoch: 5/10 Iteration: 495 Train loss: 0.809757 Train acc: 0.622070
# Epoch: 5/10 Iteration: 500 Train loss: 0.831563 Train acc: 0.561523
# Epoch: 5/10 Iteration: 505 Train loss: 0.747999 Train acc: 0.680176
# Epoch: 5/10 Iteration: 510 Train loss: 0.800706 Train acc: 0.631836
# Epoch: 6/10 Iteration: 515 Train loss: 0.768115 Train acc: 0.690430
# Epoch: 6/10 Iteration: 520 Train loss: 0.700485 Train acc: 0.717773
# Epoch: 6/10 Iteration: 520 Validation loss: 1.605466 Validation acc: 0.374138
# Epoch: 6/10 Iteration: 525 Train loss: 0.704708 Train acc: 0.702637
# Epoch: 6/10 Iteration: 530 Train loss: 0.639406 Train acc: 0.744629
# Epoch: 6/10 Iteration: 535 Train loss: 0.687371 Train acc: 0.718262
# Epoch: 6/10 Iteration: 540 Train loss: 0.499033 Train acc: 0.795898
# Epoch: 6/10 Iteration: 545 Train loss: 0.400904 Train acc: 0.840332
# Epoch: 6/10 Iteration: 550 Train loss: 0.532966 Train acc: 0.784668
# Epoch: 6/10 Iteration: 555 Train loss: 0.621365 Train acc: 0.722168
# Epoch: 6/10 Iteration: 560 Train loss: 0.488574 Train acc: 0.848633
# Epoch: 6/10 Iteration: 560 Validation loss: 1.570605 Validation acc: 0.396010
# Epoch: 6/10 Iteration: 565 Train loss: 0.681279 Train acc: 0.714844
# Epoch: 6/10 Iteration: 570 Train loss: 0.759912 Train acc: 0.679199
# Epoch: 6/10 Iteration: 575 Train loss: 0.749988 Train acc: 0.662109
# Epoch: 6/10 Iteration: 580 Train loss: 0.733428 Train acc: 0.669922
# Epoch: 6/10 Iteration: 585 Train loss: 0.770992 Train acc: 0.623535
# Epoch: 6/10 Iteration: 590 Train loss: 0.737037 Train acc: 0.671387
# Epoch: 6/10 Iteration: 595 Train loss: 0.751651 Train acc: 0.646973
# Epoch: 7/10 Iteration: 600 Train loss: 0.760438 Train acc: 0.691895
# Epoch: 7/10 Iteration: 600 Validation loss: 1.641085 Validation acc: 0.369370
# Epoch: 7/10 Iteration: 605 Train loss: 0.747716 Train acc: 0.699219
# Epoch: 7/10 Iteration: 610 Train loss: 0.722717 Train acc: 0.695312
# Epoch: 7/10 Iteration: 615 Train loss: 0.673035 Train acc: 0.728027
# Epoch: 7/10 Iteration: 620 Train loss: 0.679400 Train acc: 0.724121
# Epoch: 7/10 Iteration: 625 Train loss: 0.523281 Train acc: 0.783691
# Epoch: 7/10 Iteration: 630 Train loss: 0.384392 Train acc: 0.861816
# Epoch: 7/10 Iteration: 635 Train loss: 0.515260 Train acc: 0.788574
# Epoch: 7/10 Iteration: 640 Train loss: 0.626563 Train acc: 0.712891
# Epoch: 7/10 Iteration: 640 Validation loss: 1.540677 Validation acc: 0.386432
# Epoch: 7/10 Iteration: 645 Train loss: 0.508445 Train acc: 0.843262
# Epoch: 7/10 Iteration: 650 Train loss: 0.665167 Train acc: 0.720215
# Epoch: 7/10 Iteration: 655 Train loss: 0.763753 Train acc: 0.682129
# Epoch: 7/10 Iteration: 660 Train loss: 0.699476 Train acc: 0.708984
# Epoch: 7/10 Iteration: 665 Train loss: 0.781689 Train acc: 0.646973
# Epoch: 7/10 Iteration: 670 Train loss: 0.795788 Train acc: 0.597168
# Epoch: 7/10 Iteration: 675 Train loss: 0.717812 Train acc: 0.684082
# Epoch: 7/10 Iteration: 680 Train loss: 0.773850 Train acc: 0.627930
# Epoch: 7/10 Iteration: 680 Validation loss: 1.709890 Validation acc: 0.347513
# Epoch: 8/10 Iteration: 685 Train loss: 0.737458 Train acc: 0.687500
# Epoch: 8/10 Iteration: 690 Train loss: 0.675071 Train acc: 0.737305
# Epoch: 8/10 Iteration: 695 Train loss: 0.703653 Train acc: 0.703613
# Epoch: 8/10 Iteration: 700 Train loss: 0.659117 Train acc: 0.729980
# Epoch: 8/10 Iteration: 705 Train loss: 0.719373 Train acc: 0.714355
# Epoch: 8/10 Iteration: 710 Train loss: 0.504749 Train acc: 0.797363
# Epoch: 8/10 Iteration: 715 Train loss: 0.394581 Train acc: 0.858887
# Epoch: 8/10 Iteration: 720 Train loss: 0.494528 Train acc: 0.791016
# Epoch: 8/10 Iteration: 720 Validation loss: 1.518287 Validation acc: 0.390395
# Epoch: 8/10 Iteration: 725 Train loss: 0.577044 Train acc: 0.751953
# Epoch: 8/10 Iteration: 730 Train loss: 0.479584 Train acc: 0.841797
# Epoch: 8/10 Iteration: 735 Train loss: 0.670122 Train acc: 0.718262
# Epoch: 8/10 Iteration: 740 Train loss: 0.723904 Train acc: 0.691895
# Epoch: 8/10 Iteration: 745 Train loss: 0.720437 Train acc: 0.689453
# Epoch: 8/10 Iteration: 750 Train loss: 0.735793 Train acc: 0.660645
# Epoch: 8/10 Iteration: 755 Train loss: 0.780467 Train acc: 0.627930
# Epoch: 8/10 Iteration: 760 Train loss: 0.744287 Train acc: 0.655762
# Epoch: 8/10 Iteration: 760 Validation loss: 1.655413 Validation acc: 0.366082
# Epoch: 8/10 Iteration: 765 Train loss: 0.718355 Train acc: 0.666992
# Epoch: 9/10 Iteration: 770 Train loss: 0.697580 Train acc: 0.708008
# Epoch: 9/10 Iteration: 775 Train loss: 0.672357 Train acc: 0.725098
# Epoch: 9/10 Iteration: 780 Train loss: 0.668039 Train acc: 0.722168
# Epoch: 9/10 Iteration: 785 Train loss: 0.682652 Train acc: 0.709961
# Epoch: 9/10 Iteration: 790 Train loss: 0.659038 Train acc: 0.729492
# Epoch: 9/10 Iteration: 795 Train loss: 0.512156 Train acc: 0.809082
# Epoch: 9/10 Iteration: 800 Train loss: 0.396497 Train acc: 0.850098
# Epoch: 9/10 Iteration: 800 Validation loss: 1.553800 Validation acc: 0.383057
# Epoch: 9/10 Iteration: 805 Train loss: 0.525197 Train acc: 0.783203
# Epoch: 9/10 Iteration: 810 Train loss: 0.594987 Train acc: 0.750488
# Epoch: 9/10 Iteration: 815 Train loss: 0.532535 Train acc: 0.839844
# Epoch: 9/10 Iteration: 820 Train loss: 0.679093 Train acc: 0.714355
# Epoch: 9/10 Iteration: 825 Train loss: 0.700762 Train acc: 0.717773
# Epoch: 9/10 Iteration: 830 Train loss: 0.700042 Train acc: 0.693848
# Epoch: 9/10 Iteration: 835 Train loss: 0.766970 Train acc: 0.665527
# Epoch: 9/10 Iteration: 840 Train loss: 0.763764 Train acc: 0.637207
# Epoch: 9/10 Iteration: 840 Validation loss: 1.732341 Validation acc: 0.345028
# Epoch: 9/10 Iteration: 845 Train loss: 0.694940 Train acc: 0.689453
# Epoch: 9/10 Iteration: 850 Train loss: 0.716331 Train acc: 0.671875

# %%
# Plot training and test loss
t = np.arange(iteration-1)
tt = t[t % interation_compute_val == compute_val_at]
tt = tt[1:]
plt.figure(figsize = (16,6))
plt.plot(t, np.array(train_loss), 'r-', tt, np.array(validation_loss), 'b*')
plt.xlabel("iteration")
plt.ylabel("Loss")
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
# Plot Accuracies# Plot A 
plt.figure(figsize = (16,6))

plt.plot(t, np.array(train_acc), 'r-', tt, validation_acc, 'b*')
plt.xlabel("iteration")
plt.ylabel("Accuray")
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# Evaluate on test set

# %%
test_acc = []

with tf.Session(graph=graph) as sess:
    # Restore
    sess.run(tf.local_variables_initializer())
    saver = tf.train.import_meta_graph('checkpoints\har-lstm.ckpt.meta')
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))

    test_state = sess.run(cell.zero_state(batch_size, tf.float32))
    print(y_vld.shape)        
    for x_t, y_t in get_batches(X_vld, y_vld, batch_size): 
        feed = {inputs_: x_t,
                labels_: y_t,
                keep_prob_: 1,
                initial_state: test_state}
        
        batch_acc, test_state = sess.run([ accuracy,final_state], feed_dict=feed)
        test_acc.append(batch_acc)
        print(batch_acc)
    print("Test accuracy: {:.6f}".format(np.mean(test_acc)))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\har-lstm.ckpt
# (70626, 3)
# 0.421387
# 0.393555
# 0.483887
# 0.520508
# 0.483398
# 0.434082
# 0.399414
# 0.425781
# 0.459473
# 0.42334
# 0.48877
# 0.424805
# 0.475098
# 0.467773
# 0.282227
# 0.424805
# 0.342285
# 0.334961
# 0.19873
# 0.288574
# 0.192871
# 0.23291
# 0.258789
# 0.360352
# 0.300781
# 0.195313
# 0.171387
# 0.204102
# 0.240723
# 0.373535
# 0.35791
# 0.345215
# 0.217773
# 0.367188
# Test accuracy: 0.352697

# %%
a = np.array([[ 0,  1,  2,  0,  4,  5,  6,  7,  8,  10],
              [ 0, 11,  0, 13,  0, 15,  0, 17, 18,  0]])
print (a[a.max(axis=1) >= 10])
# Out:
# [[ 0  1  2  0  4  5  6  7  8 10]
#  [ 0 11  0 13  0 15  0 17 18  0]]

# %%
a = np.array([[ 0,  1,  2,  0,  4,  5,  6,  7,  8,  9],
              [ 0, 11,  0, 13,  0, 15,  0, 17, 18,  0]])
print (a[a[:,2]!=0])
# Out:
# [[0 1 2 0 4 5 6 7 8 9]]

# %%
print(ytest[:]!=0)
Xtest = np.array([[ 0,  1,  2,  0,  4,  5,  6,  7,  8,  9],
              [ 0, 11,  0, 13,  0, 15,  0, 17, 18,  0],
             [ 0, 11,  0, 13,  0, 15,  0, 11, 1,  1]])
ytest = np.array([ 0,  1,  1])
Xtest = Xtest[ytest[:]!=0,:]
ytest = ytest[ytest[:]!=0]
print(Xtest)
print(ytest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a2bf8e0aca21> in <module>()
# ----> 1 print(ytest[:]!=0)
#       2 Xtest = np.array([[ 0,  1,  2,  0,  4,  5,  6,  7,  8,  9],
#       3               [ 0, 11,  0, 13,  0, 15,  0, 17, 18,  0],
#       4              [ 0, 11,  0, 13,  0, 15,  0, 11, 1,  1]])
#       5 ytest = np.array([ 0,  1,  1])
#
# NameError: name 'ytest' is not defined

# %%
print(50%1)
