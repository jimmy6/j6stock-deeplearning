# %%
xfile = 'F:\workspace\j6stock\XOpenHighLowCloseVol_tp10_cl10.txt'
lstm_size = 120         # 3 times the amount of channels
lstm_layers = 2        # Number of layers
batch_size = 2048       # Batch size
learning_rate = 0.001  #0.0001  # Learning rate (default is 0.001)
epochs = 10

# Fixed
#amount_of_features_cvs = 5 # cvs with prefix with feature column
#n_channels = amount_of_features
seq_len = lstm_size
y_column = 6
compute_val_at = 0

# %%
import tensorflow as tf
from sklearn import preprocessing
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt2
import pandas as pd
from pandas import datetime
import math, time
import itertools
from sklearn import preprocessing
import datetime
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
from keras.models import load_model
import keras
import pandas_datareader.data as web
import h5py
import os
from keras import backend as K

# %%
def get_stock_data(normalize=True, ma=[]):
    """
    Return a dataframe of that stock and normalize all the values. 
    (Optional: create moving average)
    """
    df = pd.read_csv(filepath_or_buffer  = xfile )
    #TODO Use previous close instead of open
    df['change'] = df['close'] - df['open']
    for i, row in df.iterrows():
        df.at[i, 'high'] = df.at[i, 'high'] - (df.at[i, 'open'] if df.at[i, 'open'] > df.at[i, 'close'] else df.at[i, 'close'])
        df.at[i, 'low'] = (df.at[i, 'close'] if df.at[i, 'close'] < df.at[i, 'open'] else df.at[i, 'open']) - df.at[i, 'low']
    df.dropna(inplace=True)
    df = df.drop('open', axis=1)
    # Moving Average    
    if ma != []:
        for moving in ma:
            df['{}ma'.format(moving)] = df['close'].rolling(window=moving).mean()
    df.dropna(inplace=True)
    if normalize:
        min_max_scaler = preprocessing.MinMaxScaler()
        #df['open'] = min_max_scaler.fit_transform(df.open.values.reshape(-1,1))
        df['high'] = min_max_scaler.fit_transform(df.high.values.reshape(-1,1))
        df['low'] = min_max_scaler.fit_transform(df.low.values.reshape(-1,1))
        #df['vol'] = min_max_scaler.fit_transform(df.vol.values.reshape(-1,1))
        df['close'] = min_max_scaler.fit_transform(df['close'].values.reshape(-1,1))
        #df['change'] = min_max_scaler.fit_transform(df['change'].values.reshape(-1,1))
        if ma != []:
            for moving in ma:
                df['{}ma'.format(moving)] = min_max_scaler.fit_transform(df['{}ma'.format(moving)].values.reshape(-1,1))  
    df.dropna(inplace=True)
               
    # Move y_result to the rightmost for the ease of training
    adj_close = df['y_result']
    df.drop(labels=['y_result'], axis=1, inplace=True)
    df = pd.concat([df, adj_close], axis=1)
      
    return df

# %%
df = get_stock_data( ma=[50, 100, 200])
amount_of_features = len(df.columns)-1

# %%
def plot_stock(df):
    print(df.head())
    plt.subplot(211)
    plt.plot(df['close'], color='red', label='Close')
    plt.legend(loc='best')
    plt.subplot(212)
    plt.plot(df['change'], color='blue', label='Percentage change')
    plt.legend(loc='best')
    fig, (ax1, ax2) = plt.subplots(1, 2)
    ax1.plot(df['high'], color='red', label='high')
    ax1.legend(loc='best')
 
    ax2.plot(df['low'], color='red', label='low')
    ax2.legend(loc='best')
    plt.show()

# %%
plot_stock(df)
# Out:
#              high           low     close    change      50ma     100ma  \
# 199  4.445337e-14  6.182380e-03  0.357085 -0.000150  0.351429  0.351070
# 200  2.002002e-03  1.545595e-02  0.356606 -0.000060  0.351433  0.351063
# 201  1.301301e-02  7.727975e-03  0.356893  0.000035  0.351445  0.351060
# 202  4.445337e-14  1.545595e-03  0.357133  0.000015  0.351502  0.351082
# 203  6.006006e-03  6.863821e-14  0.358138  0.000095  0.351587  0.351141
#
#         200ma  y_result
# 199  0.346428         0
# 200  0.346426         0
# 201  0.346424         0
# 202  0.346433         0
# 203  0.346448         0

# %%
corr = df.corr()
ax = sns.heatmap(corr, cmap="YlGnBu")
plt.show()

# %%
def load_data(stock, seq_len):
    print ("Amount of features = {}".format(amount_of_features))
    data = stock.as_matrix()
    sequence_length = seq_len + 1 # index starting from 0
    x_result = []
    y_result = []
    for index in range(seq_len, len(data) ): # maxmimum date = lastest date - sequence length
        x_result.append(data[index-seq_len: index,:-1]) # index : index + 22days
        y_result.append(data[index ,amount_of_features]);

    #print('---', data[0])
    #print('---', x_result[0])
    #print('---', y_result[0])
    x_result = np.array(x_result)
    y_result = np.array(y_result)
    row = round(0.6 * y_result.shape[0]) # 80% split
    print ("Amount of training data = {}".format(0.9 * x_result.shape[0]))
    print ("Amount of testing data = {}".format(0.1 * y_result.shape[0]))
     
    X_train = x_result[:int(row), :] # 90% date
    y_train = y_result[:int(row)] # 90% date
        

    X_test = x_result[int(row):, :]
    y_test = y_result[int(row):]
    # filter for 1 and -1 for validation only
    X_test = X_test[y_test[:]!=0,:]
    y_test = y_test[y_test[:]!=0]
    #print(result.shape[0], len(y_result), int(row), y_result[int(row):])
    #X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], amount_of_features-1))
    #X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], amount_of_features-1))
    
    return [X_train, y_train, X_test, y_test]

# %%
lb = preprocessing.LabelBinarizer()
lb.fit([1, 0, -1])

X_tr, lab_tr, X_vld, lab_vld = load_data(df, seq_len)
y_tr = lb.transform(lab_tr)
y_vld = lb.transform(lab_vld)
print(X_tr.shape, lab_tr.shape, X_vld.shape, lab_vld.shape)
print(amount_of_features)
# Out:
# Amount of features = 7
# Amount of training data = 261918.9
# Amount of testing data = 29102.100000000002
# (174613, 120, 7) (174613,) (70626, 120, 7) (70626,)
# 7

# %%
def get_batches(X, y, batch_size = 100):
	""" Return a generator for batches """
	n_batches = len(X) // batch_size
	X, y = X[:n_batches*batch_size], y[:n_batches*batch_size]

	# Loop over batches and yield
	for b in range(0, len(X), batch_size):
		yield X[b:b+batch_size], y[b:b+batch_size]

# %%
graph = tf.Graph()
n_channels = amount_of_features
n_classes = lb.transform([1]).shape[1]
# Construct placeholders
with graph.as_default():
    inputs_ = tf.placeholder(tf.float32, [None, seq_len, n_channels], name = 'inputs')
    labels_ = tf.placeholder(tf.float32, [None, n_classes], name = 'labels')
    keep_prob_ = tf.placeholder(tf.float32, name = 'keep')
    learning_rate_ = tf.placeholder(tf.float32, name = 'learning_rate')

# %% [markdown]
# Construct inputs to LSTM

# %%
with graph.as_default():
    # Construct the LSTM inputs and LSTM cells
    lstm_in = tf.transpose(inputs_, [1,0,2]) # reshape into (seq_len, N, channels)
    lstm_in = tf.reshape(lstm_in, [-1, n_channels]) # Now (seq_len*N, n_channels)
    
    # To cells
    lstm_in = tf.layers.dense(lstm_in, lstm_size, activation=None) # or tf.nn.relu, tf.nn.sigmoid, tf.nn.tanh?
    
    # Open up the tensor into a list of seq_len pieces
    lstm_in = tf.split(lstm_in, seq_len, 0)
    
    # Add LSTM layers
    lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
    drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob_)
    cell = tf.contrib.rnn.MultiRNNCell([drop] * lstm_layers)
    initial_state = cell.zero_state(batch_size, tf.float32)

# %% [markdown]
# Define forward pass, cost function and optimizer:

# %%
with graph.as_default():
    outputs, final_state = tf.contrib.rnn.static_rnn(cell, lstm_in, dtype=tf.float32,
                                                     initial_state = initial_state)
    
    # We only need the last output tensor to pass into a classifier
    logits = tf.layers.dense(outputs[-1], n_classes, name='logits')
    
    # Cost function and optimizer
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=labels_))
    #optimizer = tf.train.AdamOptimizer(learning_rate_).minimize(cost) # No grad clipping
    
    # Grad clipping
    train_op = tf.train.AdamOptimizer(learning_rate_)

    gradients = train_op.compute_gradients(cost)
    capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients]
    optimizer = train_op.apply_gradients(capped_gradients)
    
    # Accuracy
    correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(labels_, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

# %%
if (os.path.exists('checkpoints') == False):
    # !mkdir checkpoints

# %%
interation_compute_val = 40
validation_acc = []
validation_loss = []

train_acc = []
train_loss = []

with graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    iteration = 1
    saver.restore(sess, "checkpoints/har-lstm.ckpt")
    for e in range(epochs):
        # Initialize 
        state = sess.run(initial_state)
        
        # Loop over batches
        for x,y in get_batches(X_tr, y_tr, batch_size):
            
            # Feed dictionary
            feed = {inputs_ : x, labels_ : y, keep_prob_ : 0.5, 
                    initial_state : state, learning_rate_ : learning_rate}
            
            loss, _ , state, acc = sess.run([cost, optimizer, final_state, accuracy], 
                                             feed_dict = feed)
            train_acc.append(acc)
            train_loss.append(loss)
            
            # Print at each 5 iters
            if (iteration % 5 == 0):
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {:d}".format(iteration),
                      "Train loss: {:6f}".format(loss),
                      "Train acc: {:.6f}".format(acc))
            
            # Compute validation loss at every 25 iterations
            if (iteration%interation_compute_val == compute_val_at):
                
                # Initiate for validation set
                val_state = sess.run(cell.zero_state(batch_size, tf.float32))
                
                val_acc_ = []
                val_loss_ = []
                for x_v, y_v in get_batches(X_vld, y_vld, batch_size):
                    # Feed
                    feed = {inputs_ : x_v, labels_ : y_v, keep_prob_ : 1.0, initial_state : val_state}
                    
                    # Loss
                    loss_v, state_v, acc_v = sess.run([cost, final_state, accuracy], feed_dict = feed)
                    
                    val_acc_.append(acc_v)
                    val_loss_.append(loss_v)
                
                # Print info
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {:d}".format(iteration),
                      "Validation loss: {:6f}".format(np.mean(val_loss_)),
                      "Validation acc: {:.6f}".format(np.mean(val_acc_)))
                
                # Store
                validation_acc.append(np.mean(val_acc_))
                validation_loss.append(np.mean(val_loss_))
            
            # Iterate 
            iteration += 1
    
    saver.save(sess,"checkpoints/har-lstm.ckpt")
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/har-lstm.ckpt
# Epoch: 0/10 Iteration: 5 Train loss: 0.663223 Train acc: 0.729004
# Epoch: 0/10 Iteration: 10 Train loss: 0.671095 Train acc: 0.731934
# Epoch: 0/10 Iteration: 15 Train loss: 0.721603 Train acc: 0.715820
# Epoch: 0/10 Iteration: 20 Train loss: 0.589068 Train acc: 0.768066
# Epoch: 0/10 Iteration: 25 Train loss: 0.622776 Train acc: 0.756348
# Epoch: 0/10 Iteration: 30 Train loss: 0.492965 Train acc: 0.812500
# Epoch: 0/10 Iteration: 35 Train loss: 0.360235 Train acc: 0.873535
# Epoch: 0/10 Iteration: 40 Train loss: 0.512326 Train acc: 0.784668
# Epoch: 0/10 Iteration: 40 Validation loss: 1.547157 Validation acc: 0.379883
# Epoch: 0/10 Iteration: 45 Train loss: 0.573402 Train acc: 0.755859
# Epoch: 0/10 Iteration: 50 Train loss: 0.510131 Train acc: 0.827637
# Epoch: 0/10 Iteration: 55 Train loss: 0.654885 Train acc: 0.715332
# Epoch: 0/10 Iteration: 60 Train loss: 0.700417 Train acc: 0.710449
# Epoch: 0/10 Iteration: 65 Train loss: 0.740928 Train acc: 0.666016
# Epoch: 0/10 Iteration: 70 Train loss: 0.721783 Train acc: 0.682617
# Epoch: 0/10 Iteration: 75 Train loss: 0.784956 Train acc: 0.619629
# Epoch: 0/10 Iteration: 80 Train loss: 0.692638 Train acc: 0.693848
# Epoch: 0/10 Iteration: 80 Validation loss: 1.711235 Validation acc: 0.366311
# Epoch: 0/10 Iteration: 85 Train loss: 0.742696 Train acc: 0.660645
# Epoch: 1/10 Iteration: 90 Train loss: 0.672467 Train acc: 0.725586
# Epoch: 1/10 Iteration: 95 Train loss: 0.638354 Train acc: 0.752930
# Epoch: 1/10 Iteration: 100 Train loss: 0.691730 Train acc: 0.725586
# Epoch: 1/10 Iteration: 105 Train loss: 0.607746 Train acc: 0.750488
# Epoch: 1/10 Iteration: 110 Train loss: 0.633994 Train acc: 0.752930
# Epoch: 1/10 Iteration: 115 Train loss: 0.499014 Train acc: 0.803711
# Epoch: 1/10 Iteration: 120 Train loss: 0.375912 Train acc: 0.861328
# Epoch: 1/10 Iteration: 120 Validation loss: 1.588222 Validation acc: 0.339944
# Epoch: 1/10 Iteration: 125 Train loss: 0.524890 Train acc: 0.788574
# Epoch: 1/10 Iteration: 130 Train loss: 0.594018 Train acc: 0.739746
# Epoch: 1/10 Iteration: 135 Train loss: 0.497580 Train acc: 0.842285
# Epoch: 1/10 Iteration: 140 Train loss: 0.677619 Train acc: 0.720215
# Epoch: 1/10 Iteration: 145 Train loss: 0.710995 Train acc: 0.714844
# Epoch: 1/10 Iteration: 150 Train loss: 0.719660 Train acc: 0.677246
# Epoch: 1/10 Iteration: 155 Train loss: 0.717956 Train acc: 0.677734
# Epoch: 1/10 Iteration: 160 Train loss: 0.755075 Train acc: 0.634766
# Epoch: 1/10 Iteration: 160 Validation loss: 1.780216 Validation acc: 0.355325
# Epoch: 1/10 Iteration: 165 Train loss: 0.698982 Train acc: 0.675781
# Epoch: 1/10 Iteration: 170 Train loss: 0.747773 Train acc: 0.655762
# Epoch: 2/10 Iteration: 175 Train loss: 0.703531 Train acc: 0.716309
# Epoch: 2/10 Iteration: 180 Train loss: 0.657311 Train acc: 0.731445
# Epoch: 2/10 Iteration: 185 Train loss: 0.679599 Train acc: 0.729004
# Epoch: 2/10 Iteration: 190 Train loss: 0.533035 Train acc: 0.794922
# Epoch: 2/10 Iteration: 195 Train loss: 0.633168 Train acc: 0.749023
# Epoch: 2/10 Iteration: 200 Train loss: 0.470265 Train acc: 0.828125
# Epoch: 2/10 Iteration: 200 Validation loss: 1.549871 Validation acc: 0.366225
# Epoch: 2/10 Iteration: 205 Train loss: 0.353690 Train acc: 0.872070
# Epoch: 2/10 Iteration: 210 Train loss: 0.532671 Train acc: 0.783691
# Epoch: 2/10 Iteration: 215 Train loss: 0.621923 Train acc: 0.729004
# Epoch: 2/10 Iteration: 220 Train loss: 0.471479 Train acc: 0.857422
# Epoch: 2/10 Iteration: 225 Train loss: 0.689307 Train acc: 0.701660
# Epoch: 2/10 Iteration: 230 Train loss: 0.710225 Train acc: 0.691895
# Epoch: 2/10 Iteration: 235 Train loss: 0.690601 Train acc: 0.701172
# Epoch: 2/10 Iteration: 240 Train loss: 0.709111 Train acc: 0.678711
# Epoch: 2/10 Iteration: 240 Validation loss: 1.728118 Validation acc: 0.384191
# Epoch: 2/10 Iteration: 245 Train loss: 0.788698 Train acc: 0.616211
# Epoch: 2/10 Iteration: 250 Train loss: 0.664781 Train acc: 0.711426
# Epoch: 2/10 Iteration: 255 Train loss: 0.758731 Train acc: 0.634277
# Epoch: 3/10 Iteration: 260 Train loss: 0.707158 Train acc: 0.710938
# Epoch: 3/10 Iteration: 265 Train loss: 0.649890 Train acc: 0.721191
# Epoch: 3/10 Iteration: 270 Train loss: 0.651208 Train acc: 0.736328
# Epoch: 3/10 Iteration: 275 Train loss: 0.576375 Train acc: 0.767578
# Epoch: 3/10 Iteration: 280 Train loss: 0.606072 Train acc: 0.770508
# Epoch: 3/10 Iteration: 280 Validation loss: 1.544324 Validation acc: 0.371252
# Epoch: 3/10 Iteration: 285 Train loss: 0.474139 Train acc: 0.825195
# Epoch: 3/10 Iteration: 290 Train loss: 0.369612 Train acc: 0.866211
# Epoch: 3/10 Iteration: 295 Train loss: 0.479843 Train acc: 0.802246
# Epoch: 3/10 Iteration: 300 Train loss: 0.564931 Train acc: 0.759277
# Epoch: 3/10 Iteration: 305 Train loss: 0.479094 Train acc: 0.854004
# Epoch: 3/10 Iteration: 310 Train loss: 0.651976 Train acc: 0.726562
# Epoch: 3/10 Iteration: 315 Train loss: 0.688467 Train acc: 0.713867
# Epoch: 3/10 Iteration: 320 Train loss: 0.721814 Train acc: 0.676270
# Epoch: 3/10 Iteration: 320 Validation loss: 1.665689 Validation acc: 0.374512
# Epoch: 3/10 Iteration: 325 Train loss: 0.714727 Train acc: 0.677246
# Epoch: 3/10 Iteration: 330 Train loss: 0.769747 Train acc: 0.640137
# Epoch: 3/10 Iteration: 335 Train loss: 0.674147 Train acc: 0.705078
# Epoch: 3/10 Iteration: 340 Train loss: 0.773350 Train acc: 0.629883
# Epoch: 4/10 Iteration: 345 Train loss: 0.706702 Train acc: 0.713867
# Epoch: 4/10 Iteration: 350 Train loss: 0.647441 Train acc: 0.722168
# Epoch: 4/10 Iteration: 355 Train loss: 0.692474 Train acc: 0.718262
# Epoch: 4/10 Iteration: 360 Train loss: 0.566303 Train acc: 0.771973
# Epoch: 4/10 Iteration: 360 Validation loss: 1.532472 Validation acc: 0.348963
# Epoch: 4/10 Iteration: 365 Train loss: 0.587467 Train acc: 0.765625
# Epoch: 4/10 Iteration: 370 Train loss: 0.455945 Train acc: 0.820801
# Epoch: 4/10 Iteration: 375 Train loss: 0.371291 Train acc: 0.863281
# Epoch: 4/10 Iteration: 380 Train loss: 0.523190 Train acc: 0.777344
# Epoch: 4/10 Iteration: 385 Train loss: 0.577810 Train acc: 0.741699
# Epoch: 4/10 Iteration: 390 Train loss: 0.500662 Train acc: 0.835449
# Epoch: 4/10 Iteration: 395 Train loss: 0.635578 Train acc: 0.729492
# Epoch: 4/10 Iteration: 400 Train loss: 0.684493 Train acc: 0.723145
# Epoch: 4/10 Iteration: 400 Validation loss: 1.696701 Validation acc: 0.368782
# Epoch: 4/10 Iteration: 405 Train loss: 0.724258 Train acc: 0.667480
# Epoch: 4/10 Iteration: 410 Train loss: 0.753002 Train acc: 0.661133
# Epoch: 4/10 Iteration: 415 Train loss: 0.767595 Train acc: 0.614746
# Epoch: 4/10 Iteration: 420 Train loss: 0.652230 Train acc: 0.720703
# Epoch: 4/10 Iteration: 425 Train loss: 0.771956 Train acc: 0.619629
# Epoch: 5/10 Iteration: 430 Train loss: 0.674167 Train acc: 0.725586
# Epoch: 5/10 Iteration: 435 Train loss: 0.669598 Train acc: 0.732910
# Epoch: 5/10 Iteration: 440 Train loss: 0.683903 Train acc: 0.716797
# Epoch: 5/10 Iteration: 440 Validation loss: 1.692807 Validation acc: 0.349810
# Epoch: 5/10 Iteration: 445 Train loss: 0.570342 Train acc: 0.767578
# Epoch: 5/10 Iteration: 450 Train loss: 0.644692 Train acc: 0.740723
# Epoch: 5/10 Iteration: 455 Train loss: 0.470693 Train acc: 0.812012
# Epoch: 5/10 Iteration: 460 Train loss: 0.399584 Train acc: 0.846191
# Epoch: 5/10 Iteration: 465 Train loss: 0.604886 Train acc: 0.774414
# Epoch: 5/10 Iteration: 470 Train loss: 0.645158 Train acc: 0.708496
# Epoch: 5/10 Iteration: 475 Train loss: 0.511489 Train acc: 0.836914
# Epoch: 5/10 Iteration: 480 Train loss: 0.640623 Train acc: 0.739746
# Epoch: 5/10 Iteration: 480 Validation loss: 1.495091 Validation acc: 0.387107
# Epoch: 5/10 Iteration: 485 Train loss: 0.709426 Train acc: 0.703613
# Epoch: 5/10 Iteration: 490 Train loss: 0.679775 Train acc: 0.718750
# Epoch: 5/10 Iteration: 495 Train loss: 0.703782 Train acc: 0.675781
# Epoch: 5/10 Iteration: 500 Train loss: 0.745415 Train acc: 0.645996
# Epoch: 5/10 Iteration: 505 Train loss: 0.692485 Train acc: 0.674805
# Epoch: 5/10 Iteration: 510 Train loss: 0.694511 Train acc: 0.681152
# Epoch: 6/10 Iteration: 515 Train loss: 0.688863 Train acc: 0.722168
# Epoch: 6/10 Iteration: 520 Train loss: 0.701871 Train acc: 0.705566
# Epoch: 6/10 Iteration: 520 Validation loss: 1.573447 Validation acc: 0.383559
# Epoch: 6/10 Iteration: 525 Train loss: 0.691644 Train acc: 0.720215
# Epoch: 6/10 Iteration: 530 Train loss: 0.541643 Train acc: 0.793945
# Epoch: 6/10 Iteration: 535 Train loss: 0.605583 Train acc: 0.764648
# Epoch: 6/10 Iteration: 540 Train loss: 0.543313 Train acc: 0.791992
# Epoch: 6/10 Iteration: 545 Train loss: 0.382843 Train acc: 0.861328
# Epoch: 6/10 Iteration: 550 Train loss: 0.561594 Train acc: 0.770508
# Epoch: 6/10 Iteration: 555 Train loss: 0.597337 Train acc: 0.750000
# Epoch: 6/10 Iteration: 560 Train loss: 0.509582 Train acc: 0.829102
# Epoch: 6/10 Iteration: 560 Validation loss: 1.551948 Validation acc: 0.387351
# Epoch: 6/10 Iteration: 565 Train loss: 0.636791 Train acc: 0.729004
# Epoch: 6/10 Iteration: 570 Train loss: 0.701551 Train acc: 0.711426
# Epoch: 6/10 Iteration: 575 Train loss: 0.678714 Train acc: 0.721191
# Epoch: 6/10 Iteration: 580 Train loss: 0.668129 Train acc: 0.707031
# Epoch: 6/10 Iteration: 585 Train loss: 0.773001 Train acc: 0.609863
# Epoch: 6/10 Iteration: 590 Train loss: 0.658168 Train acc: 0.711426
# Epoch: 6/10 Iteration: 595 Train loss: 0.717274 Train acc: 0.671387
# Epoch: 7/10 Iteration: 600 Train loss: 0.666164 Train acc: 0.723145
# Epoch: 7/10 Iteration: 600 Validation loss: 1.680077 Validation acc: 0.369428
# Epoch: 7/10 Iteration: 605 Train loss: 0.633021 Train acc: 0.745605
# Epoch: 7/10 Iteration: 610 Train loss: 0.643475 Train acc: 0.730469
# Epoch: 7/10 Iteration: 615 Train loss: 0.567312 Train acc: 0.769531
# Epoch: 7/10 Iteration: 620 Train loss: 0.601299 Train acc: 0.754883
# Epoch: 7/10 Iteration: 625 Train loss: 0.488115 Train acc: 0.812500
# Epoch: 7/10 Iteration: 630 Train loss: 0.386896 Train acc: 0.864258
# Epoch: 7/10 Iteration: 635 Train loss: 0.506146 Train acc: 0.778809
# Epoch: 7/10 Iteration: 640 Train loss: 0.656072 Train acc: 0.710938
# Epoch: 7/10 Iteration: 640 Validation loss: 1.533250 Validation acc: 0.374038
# Epoch: 7/10 Iteration: 645 Train loss: 0.508602 Train acc: 0.846191
# Epoch: 7/10 Iteration: 650 Train loss: 0.631287 Train acc: 0.736816
# Epoch: 7/10 Iteration: 655 Train loss: 0.698099 Train acc: 0.697266
# Epoch: 7/10 Iteration: 660 Train loss: 0.664027 Train acc: 0.725098
# Epoch: 7/10 Iteration: 665 Train loss: 0.670481 Train acc: 0.700195
# Epoch: 7/10 Iteration: 670 Train loss: 0.773361 Train acc: 0.614746
# Epoch: 7/10 Iteration: 675 Train loss: 0.681522 Train acc: 0.682617
# Epoch: 7/10 Iteration: 680 Train loss: 0.730692 Train acc: 0.659668
# Epoch: 7/10 Iteration: 680 Validation loss: 1.515980 Validation acc: 0.411075
# Epoch: 8/10 Iteration: 685 Train loss: 0.691293 Train acc: 0.712891
# Epoch: 8/10 Iteration: 690 Train loss: 0.629378 Train acc: 0.755371
# Epoch: 8/10 Iteration: 695 Train loss: 0.633491 Train acc: 0.739258
# Epoch: 8/10 Iteration: 700 Train loss: 0.570297 Train acc: 0.778809
# Epoch: 8/10 Iteration: 705 Train loss: 0.600267 Train acc: 0.766113
# Epoch: 8/10 Iteration: 710 Train loss: 0.458286 Train acc: 0.825684
# Epoch: 8/10 Iteration: 715 Train loss: 0.356489 Train acc: 0.872070
# Epoch: 8/10 Iteration: 720 Train loss: 0.499704 Train acc: 0.790527
# Epoch: 8/10 Iteration: 720 Validation loss: 1.687226 Validation acc: 0.373722
# Epoch: 8/10 Iteration: 725 Train loss: 0.559265 Train acc: 0.770020
# Epoch: 8/10 Iteration: 730 Train loss: 0.465976 Train acc: 0.846680
# Epoch: 8/10 Iteration: 735 Train loss: 0.646985 Train acc: 0.729980
# Epoch: 8/10 Iteration: 740 Train loss: 0.704818 Train acc: 0.700684
# Epoch: 8/10 Iteration: 745 Train loss: 0.690981 Train acc: 0.709473
# Epoch: 8/10 Iteration: 750 Train loss: 0.724704 Train acc: 0.687500
# Epoch: 8/10 Iteration: 755 Train loss: 0.772943 Train acc: 0.621094
# Epoch: 8/10 Iteration: 760 Train loss: 0.704070 Train acc: 0.693848
# Epoch: 8/10 Iteration: 760 Validation loss: 1.584020 Validation acc: 0.396642
# Epoch: 8/10 Iteration: 765 Train loss: 0.758860 Train acc: 0.645996
# Epoch: 9/10 Iteration: 770 Train loss: 0.681224 Train acc: 0.731934
# Epoch: 9/10 Iteration: 775 Train loss: 0.627521 Train acc: 0.753906
# Epoch: 9/10 Iteration: 780 Train loss: 0.642547 Train acc: 0.731934
# Epoch: 9/10 Iteration: 785 Train loss: 0.480058 Train acc: 0.831055
# Epoch: 9/10 Iteration: 790 Train loss: 0.618000 Train acc: 0.749023
# Epoch: 9/10 Iteration: 795 Train loss: 0.469752 Train acc: 0.817871
# Epoch: 9/10 Iteration: 800 Train loss: 0.404950 Train acc: 0.856934
# Epoch: 9/10 Iteration: 800 Validation loss: 1.740380 Validation acc: 0.393727
# Epoch: 9/10 Iteration: 805 Train loss: 0.487543 Train acc: 0.789551
# Epoch: 9/10 Iteration: 810 Train loss: 0.566194 Train acc: 0.778809
# Epoch: 9/10 Iteration: 815 Train loss: 0.472174 Train acc: 0.853516
# Epoch: 9/10 Iteration: 820 Train loss: 0.640361 Train acc: 0.731934
# Epoch: 9/10 Iteration: 825 Train loss: 0.673676 Train acc: 0.722168
# Epoch: 9/10 Iteration: 830 Train loss: 0.721397 Train acc: 0.685059
# Epoch: 9/10 Iteration: 835 Train loss: 0.804827 Train acc: 0.634766
# Epoch: 9/10 Iteration: 840 Train loss: 0.766135 Train acc: 0.627441
# Epoch: 9/10 Iteration: 840 Validation loss: 1.577715 Validation acc: 0.390151
# Epoch: 9/10 Iteration: 845 Train loss: 0.675693 Train acc: 0.694824
# Epoch: 9/10 Iteration: 850 Train loss: 0.685228 Train acc: 0.687012

# %%
# Plot training and test loss
t = np.arange(iteration-1)
tt = t[t % interation_compute_val == compute_val_at]
tt = tt[1:]
plt.figure(figsize = (16,6))
plt.plot(t, np.array(train_loss), 'r-', tt, np.array(validation_loss), 'b*')
plt.xlabel("iteration")
plt.ylabel("Loss")
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
# Plot Accuracies# Plot A 
plt.figure(figsize = (16,6))

plt.plot(t, np.array(train_acc), 'r-', tt, validation_acc, 'b*')
plt.xlabel("iteration")
plt.ylabel("Accuray")
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# Evaluate on test set

# %%
test_acc = []

with tf.Session(graph=graph) as sess:
    # Restore
    sess.run(tf.local_variables_initializer())
    saver = tf.train.import_meta_graph('checkpoints\har-lstm.ckpt.meta')
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))

    test_state = sess.run(cell.zero_state(batch_size, tf.float32))
    print(y_vld.shape)        
    for x_t, y_t in get_batches(X_vld, y_vld, batch_size): 
        feed = {inputs_: x_t,
                labels_: y_t,
                keep_prob_: 1,
                initial_state: test_state}
        
        batch_acc, test_state = sess.run([ accuracy,final_state], feed_dict=feed)
        test_acc.append(batch_acc)
        print(batch_acc)
    print("Test accuracy: {:.6f}".format(np.mean(test_acc)))

import datetime
print datetime.datetime.now().strftime("%Y-%m-%d %H:%M")
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\har-lstm.ckpt
# (70626, 3)
# 0.438477
# 0.397949
# 0.462891
# 0.537598
# 0.495605
# 0.385254
# 0.369629
# 0.484863
# 0.441895
# 0.395508
# 0.429199
# 0.466797
# 0.432129
# 0.460938
# 0.285156
# 0.429199
# 0.40332
# 0.395508
# 0.291504
# 0.392578
# 0.302734
# 0.351074
# 0.333984
# 0.366211
# 0.416504
# 0.339844
# 0.313477
# 0.268555
# 0.394531
# 0.409668
# 0.332031
# 0.32373
# 0.321777
# 0.415039
# Test accuracy: 0.390740

# %%
a = np.array([[ 0,  1,  2,  0,  4,  5,  6,  7,  8,  10],
              [ 0, 11,  0, 13,  0, 15,  0, 17, 18,  0]])
print (a[a.max(axis=1) >= 11])
# Out:
# [[ 0 11  0 13  0 15  0 17 18  0]]

# %%
import numpy as np
a = np.array([[ 0,  1,  2,  0,  4,  5,  6,  7,  8,  9],
              [ 0, 11,  0, 13,  0, 15,  0, 17, 18,  0]])
print (a[a[:]>1])
# Out:
# [ 2  4  5  6  7  8  9 11 13 15 17 18]

# %%
print(ytest[:]!=0)
Xtest = np.array([[ 0,  1,  2,  0,  4,  5,  6,  7,  8,  9],
              [ 0, 11,  0, 13,  0, 15,  0, 17, 18,  0],
             [ 0, 11,  0, 13,  0, 15,  0, 11, 1,  1]])
ytest = np.array([ 0,  1,  1])
Xtest = Xtest[ytest[:]!=0,:]
ytest = ytest[ytest[:]!=0]
print(Xtest)
print(ytest)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-a2bf8e0aca21> in <module>()
# ----> 1 print(ytest[:]!=0)
#       2 Xtest = np.array([[ 0,  1,  2,  0,  4,  5,  6,  7,  8,  9],
#       3               [ 0, 11,  0, 13,  0, 15,  0, 17, 18,  0],
#       4              [ 0, 11,  0, 13,  0, 15,  0, 11, 1,  1]])
#       5 ytest = np.array([ 0,  1,  1])
#
# NameError: name 'ytest' is not defined

# %%
print(50%1)

# %%
 
meta_path = 'checkpoints\har-lstm.ckpt.meta' # Your .meta file
#output_node_names = ['logits:0']    # Output nodes

with tf.Session() as sess:

    # Restore the graph
    saver = tf.train.import_meta_graph(meta_path)

    # Load weights
    saver.restore(sess,tf.train.latest_checkpoint('checkpoints'))
    node_names = [node.name for node in tf.get_default_graph().as_graph_def().node]
    print(node_names)
    # Freeze the graph
    frozen_graph_def = tf.graph_util.convert_variables_to_constants(
        sess,
        sess.graph_def,
        node_names)

    # Save the frozen graph
    with open('checkpoints\output_graph.pb', 'wb') as f:
      f.write(frozen_graph_def.SerializeToString())
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\har-lstm.ckpt
# ['inputs', 'labels', 'keep', 'learning_rate', 'transpose/perm', 'transpose', 'Reshape/shape', 'Reshape', 'dense/kernel/Initializer/random_uniform/shape', 'dense/kernel/Initializer/random_uniform/min', 'dense/kernel/Initializer/random_uniform/max', 'dense/kernel/Initializer/random_uniform/RandomUniform', 'dense/kernel/Initializer/random_uniform/sub', 'dense/kernel/Initializer/random_uniform/mul', 'dense/kernel/Initializer/random_uniform', 'dense/kernel', 'dense/kernel/Assign', 'dense/kernel/read', 'dense/bias/Initializer/zeros', 'dense/bias', 'dense/bias/Assign', 'dense/bias/read', 'dense/MatMul', 'dense/BiasAdd', 'Const', 'split/split_dim', 'split', 'DropoutWrapperInit/Const', 'DropoutWrapperInit/Const_1', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/Const', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/Const_1', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/concat/axis', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/concat', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/Const_2', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/Const_3', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/zeros/Const', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/zeros', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/Const_4', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/Const_5', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/concat_1/axis', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/concat_1', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/Const_6', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/Const_7', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/zeros_1/Const', 'MultiRNNCellZeroState/DropoutWrapperZeroState/BasicLSTMCellZeroState/zeros_1', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/Const', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/Const_1', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/concat/axis', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/concat', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/Const_2', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/Const_3', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/zeros/Const', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/zeros', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/Const_4', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/Const_5', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/concat_1/axis', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/concat_1', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/Const_6', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/Const_7', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/zeros_1/Const', 'MultiRNNCellZeroState/DropoutWrapperZeroState_1/BasicLSTMCellZeroState/zeros_1', 'rnn/Shape', 'rnn/strided_slice/stack', 'rnn/strided_slice/stack_1', 'rnn/strided_slice/stack_2', 'rnn/strided_slice', 'rnn/multi_rnn_cell/cell_0/basic_lstm_cell/kernel/Initializer/random_uniform/shape', 'rnn/multi_rnn_cell/cell_0/basic_lstm_cell/kernel/Initializer/random_uniform/min', 'rnn/multi_rnn_cell/cell_0/basic_lstm_cell/kernel/Initializer/random_uniform/max', 'rnn/multi_rnn_cell/cell_0/basic_lstm_cell/kernel/Initializer/random_uniform/RandomUniform', 'rnn/multi_rnn_cell/cell_0/basic_lstm_cell/kernel/Initializer/random_uniform/sub', 'rnn/multi_rnn_cell/cell_0/basic_lstm_cell/kernel/Initializer/random_uniform/mul', 'rnn/multi_rnn_cell/cell_0/basi ...
# INFO:tensorflow:Froze 20 variables.
# Converted 20 variables to const ops.

# %%
a = np.array([[ 0,  1,  2,  0,  4,  5,  6,  7,  8,  10],
              [ 0, 11,  0, 13,  0, 15,  0, 17, 18,  0]])
tf.InteractiveSession()

t = tf.constant(a)

t1 = tf.boolean_mask(t, tf.reduce_max(t, axis=1) >= 11)

t1.eval()
# array([[ 0, 11,  0, 13,  0, 15,  0, 17, 18,  0]])
# Out:
# array([[ 0, 11,  0, 13,  0, 15,  0, 17, 18,  0]])

# %%
print(tf.__version__)
# Out:
# 1.3.0
